# %% [markdown]
# <a href="https://colab.research.google.com/github/ndb796/Deep-Learning-Paper-Review-and-Practice/blob/master/code_practices/ResNet18_CIFAR10_Training_with_Input_Mixup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### <b>ResNet18 모델 아키텍처 정의</b>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out) # 출력: [batch_size, 512, 4, 4]
        out = F.avg_pool2d(out, 4) # 출력: [batch_size, 512, 1, 1]
        out = out.view(out.size(0), -1) # 출력: [batch_size, 512]
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### <b>데이터셋(Dataset) 다운로드 및 불러오기</b>

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# #### <b>필요한 라이브러리 구현</b>

# %%
import numpy as np

mixup_alpha = 1.0

def mixup_data(x, y):
    lam = np.random.beta(mixup_alpha, mixup_alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %% [markdown]
# #### <b>환경 설정 및 학습(Training) 함수 정의</b>

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)

learning_rate = 0.1
file_name = 'resnet18_cifar10.pth'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets)
        optimizer.zero_grad()

        outputs = net(inputs)
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        current_correct = (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())
        correct += current_correct

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current batch average train accuracy:', current_correct / targets.size(0))
            print('Current batch average train loss:', loss.item() / targets.size(0))

    print('\nTotal average train accuarcy:', correct / total)
    print('Total average train loss:', train_loss / total)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTotal average test accuarcy:', correct / total)
    print('Total average test loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %% [markdown]
# #### <b>학습(Training) 진행</b>

# %%
import time


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 50:
        lr /= 10
    if epoch >= 100:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

start_time = time.time()

for epoch in range(0, 150):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
    print('\nTime elapsed:', time.time() - start_time)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.09727836367854385
# Current batch average train loss: 0.018746694549918175
#
# Current batch: 100
# Current batch average train accuracy: 0.23465121261291963
# Current batch average train loss: 0.016454745084047318
#
# Current batch: 200
# Current batch average train accuracy: 0.333794545157437
# Current batch average train loss: 0.014404334127902985
#
# Current batch: 300
# Current batch average train accuracy: 0.26906486580878847
# Current batch average train loss: 0.015901871025562286
#
# Total average train accuarcy: 0.2438999810762169
# Total average train loss: 0.01657938927412033
#
# [ Test epoch: 0 ]
#
# Total average test accuarcy: 0.2885
# Total average test loss: 0.019975642216205597
# Model Saved!
#
# Time elapsed: 67.31932187080383
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.24919886781709963
# Current batch average train loss: 0.015324986539781094
#
# Current batch: 100
# Current batch average train accuracy: 0.4636160828714663
# Current batch average train loss: 0.012422642670571804
#
# Current batch: 200
# Current batch average train accuracy: 0.34419466939811794
# Current batch average train loss: 0.015307758003473282
#
# Current batch: 300
# Current batch average train accuracy: 0.31797102300464986
# Current batch average train loss: 0.01510600931942463
#
# Total average train accuarcy: 0.35010402917211925
# Total average train loss: 0.014451653120517731
#
# [ Test epoch: 1 ]
#
# Total average test accuarcy: 0.4511
# Total average test loss: 0.015768038177490236
# Model Saved!
#
# Time elapsed: 134.12930130958557
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.39064543301020394
# Current batch average train loss: 0.01368321105837822
#
# Current batch: 100
# Current batch average train accuracy: 0.4536923300926184
# Current batch average train loss: 0.013418509624898434
#
# Current batch: 200
# Current batch average train accuracy: 0.5843046093906161
# Current batch average train loss: 0.010685338638722897
#
# Current batch: 300
# Current batch average train accuracy: 0.4138342762235759
# Current batch average train loss: 0.013748647645115852
#
# Total average train accuarcy: 0.42018612307862413
# Total average train loss: 0.01337722238779068
#
# [ Test epoch: 2 ]
#
# Total average test accuarcy: 0.3748
# Total average test loss: 0.01846726050376892
# Model Saved!
#
# Time elapsed: 200.83397006988525
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6173987355731223
# Current batch average train loss: 0.00914319884032011
#
# Current batch: 100
# Current batch average train accuracy: 0.5900493613504846
# Current batch average train loss: 0.009842365980148315
#
# Current batch: 200
# Current batch average train accuracy: 0.5708004272097587
# Current batch average train loss: 0.010575332678854465
#
# Current batch: 300
# Current batch average train accuracy: 0.5454333471487535
# Current batch average train loss: 0.011715037748217583
#
# Total average train accuarcy: 0.4552326009648567
# Total average train loss: 0.012816074323654175
#
# [ Test epoch: 3 ]
#
# Total average test accuarcy: 0.542
# Total average test loss: 0.013031093001365662
# Model Saved!
#
# Time elapsed: 267.6033661365509
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5670800999019762
# Current batch average train loss: 0.011077708564698696
#
# Current batch: 100
# Current batch average train accuracy: 0.33942700380630286
# Current batch average train loss: 0.01571563258767128
#
# Current batch: 200
# Current batch average train accuracy: 0.5527230620729884
# Current batch average train loss: 0.011261177249252796
#
# Current batch: 300
# Current batch average train accuracy: 0.41191504465987094
# Current batch average train loss: 0.01367579773068428
#
# Total average train accuarcy: 0.4815957606387106
# Total average train loss: 0.012333299213647843
#
# [ Test epoch: 4 ]
#
# Total average test accuarcy: 0.533
# Total average test loss: 0.013741466772556304
# Model Saved!
#
# Time elapsed: 334.2372772693634
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.32909885804028555
# Current batch average train loss: 0.014123043045401573
#
# Current batch: 100
# Current batch average train accuracy: 0.35232902116638143
# Current batch average train loss: 0.01461983285844326
#
# Current batch: 200
# Current batch average train accuracy: 0.40546838587707035
# Current batch average train loss: 0.01375819556415081
#
# Current batch: 300
# Current batch average train accuracy: 0.37276580497994516
# Current batch average train loss: 0.014229300431907177
#
# Total average train accuarcy: 0.5138012749180852
# Total average train loss: 0.011761493802070618
#
# [ Test epoch: 5 ]
#
# Total average test accuarcy: 0.6636
# Total average test loss: 0.010204350268840789
# Model Saved!
#
# Time elapsed: 400.89489698410034
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4859315226893304
# Current batch average train loss: 0.012627273797988892
#
# Current batch: 100
# Current batch average train accuracy: 0.4099717220535597
# Current batch average train loss: 0.013684434816241264
#
# Current batch: 200
# Current batch average train accuracy: 0.7072205058748521
# Current batch average train loss: 0.0078122615814208984
#
# Current batch: 300
# Current batch average train accuracy: 0.4435237277726132
# Current batch average train loss: 0.013115045614540577
#
# Total average train accuarcy: 0.5430234982488837
# Total average train loss: 0.011276201122999192
#
# [ Test epoch: 6 ]
#
# Total average test accuarcy: 0.6475
# Total average test loss: 0.010523168969154359
# Model Saved!
#
# Time elapsed: 467.57990646362305
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6297623337920402
# Current batch average train loss: 0.010165085084736347
#
# Current batch: 100
# Current batch average train accuracy: 0.6370089383482624
# Current batch average train loss: 0.009543618187308311
#
# Current batch: 200
# Current batch average train accuracy: 0.4830356924365709
# Current batch average train loss: 0.01263895258307457
#
# Current batch: 300
# Current batch average train accuracy: 0.48627439472570266
# Current batch average train loss: 0.01262323372066021
#
# Total average train accuarcy: 0.5658904739480652
# Total average train loss: 0.01078166707277298
#
# [ Test epoch: 7 ]
#
# Total average test accuarcy: 0.7351
# Total average test loss: 0.008803094333410264
# Model Saved!
#
# Time elapsed: 534.4943442344666
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6179928894647404
# Current batch average train loss: 0.01031770184636116
#
# Current batch: 100
# Current batch average train accuracy: 0.4461918547591837
# Current batch average train loss: 0.013237190432846546
#
# Current batch: 200
# Current batch average train accuracy: 0.437434791532017
# Current batch average train loss: 0.012683529406785965
#
# Current batch: 300
# Current batch average train accuracy: 0.575830526296256
# Current batch average train loss: 0.01113214623183012
#
# Total average train accuarcy: 0.5788749931425785
# Total average train loss: 0.01062203551530838
#
# [ Test epoch: 8 ]
#
# Total average test accuarcy: 0.7095
# Total average test loss: 0.009076267409324646
# Model Saved!
#
# Time elapsed: 601.1747407913208
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6525943929354701
# Current batch average train loss: 0.009136104956269264
#
# Current batch: 100
# Current batch average train accuracy: 0.4819095752220173
# Current batch average train loss: 0.01225016824901104
#
# Current batch: 200
# Current batch average train accuracy: 0.4268182041022082
# Current batch average train loss: 0.012797015719115734
#
# Current batch: 300
# Current batch average train accuracy: 0.49720414690439
# Current batch average train loss: 0.012337896041572094
#
# Total average train accuarcy: 0.5839467842568282
# Total average train loss: 0.010511346663236618
#
# [ Test epoch: 9 ]
#
# Total average test accuarcy: 0.7276
# Total average test loss: 0.008879742527008056
# Model Saved!
#
# Time elapsed: 667.8142864704132
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7178603226344424
# Current batch average train loss: 0.007616589777171612
#
# Current batch: 100
# Current batch average train accuracy: 0.6975085007000397
# Current batch average train loss: 0.008920421823859215
#
# Current batch: 200
# Current batch average train accuracy: 0.6220718926364055
# Current batch average train loss: 0.010429859161376953
#
# Current batch: 300
# Current batch average train accuracy: 0.4618727088078343
# Current batch average train loss: 0.012916531413793564
#
# Total average train accuarcy: 0.6016285790264628
# Total average train loss: 0.010106802842617035
#
# [ Test epoch: 10 ]
#
# Total average test accuarcy: 0.7199
# Total average test loss: 0.008745429641008377
# Model Saved!
#
# Time elapsed: 734.5619456768036
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4219043275471749
# Current batch average train loss: 0.013182992115616798
#
# Current batch: 100
# Current batch average train accuracy: 0.6511148120217487
# Current batch average train loss: 0.010063281282782555
#
# Current batch: 200
# Current batch average train accuracy: 0.740341836708163
# Current batch average train loss: 0.00755461398512125
#
# Current batch: 300
# Current batch average train accuracy: 0.8213815048950152
# Current batch average train loss: 0.004997447598725557
#
# Total average train accuarcy: 0.6096975259085268
# Total average train loss: 0.009987703077197076
#
# [ Test epoch: 11 ]
#
# Total average test accuarcy: 0.7646
# Total average test loss: 0.007680280905961991
# Model Saved!
#
# Time elapsed: 801.3842809200287
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6617535001141703
# Current batch average train loss: 0.008984318003058434
#
# Current batch: 100
# Current batch average train accuracy: 0.6308431080735917
# Current batch average train loss: 0.010096214711666107
#
# Current batch: 200
# Current batch average train accuracy: 0.43816233190509773
# Current batch average train loss: 0.012839829549193382
#
# Current batch: 300
# Current batch average train accuracy: 0.6357544708714679
# Current batch average train loss: 0.009972522035241127
#
# Total average train accuarcy: 0.6199243457839402
# Total average train loss: 0.009749777668714524
#
# [ Test epoch: 12 ]
#
# Total average test accuarcy: 0.777
# Total average test loss: 0.007399796807765961
# Model Saved!
#
# Time elapsed: 868.0868828296661
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.44815357209391793
# Current batch average train loss: 0.012733022682368755
#
# Current batch: 100
# Current batch average train accuracy: 0.4778757776836638
# Current batch average train loss: 0.01197742111980915
#
# Current batch: 200
# Current batch average train accuracy: 0.7937129235829692
# Current batch average train loss: 0.0061811646446585655
#
# Current batch: 300
# Current batch average train accuracy: 0.6306109508019635
# Current batch average train loss: 0.010059140622615814
#
# Total average train accuarcy: 0.6335418792071775
# Total average train loss: 0.009478528788685799
#
# [ Test epoch: 13 ]
#
# Total average test accuarcy: 0.7944
# Total average test loss: 0.006542516574263572
# Model Saved!
#
# Time elapsed: 934.8241033554077
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5875568833773117
# Current batch average train loss: 0.011232482269406319
#
# Current batch: 100
# Current batch average train accuracy: 0.8639689000154441
# Current batch average train loss: 0.004735847003757954
#
# Current batch: 200
# Current batch average train accuracy: 0.5827944272753317
# Current batch average train loss: 0.011070692911744118
#
# Current batch: 300
# Current batch average train accuracy: 0.44645285577917937
# Current batch average train loss: 0.012984460219740868
#
# Total average train accuarcy: 0.62095292169662
# Total average train loss: 0.00972314892232418
#
# [ Test epoch: 14 ]
#
# Total average test accuarcy: 0.8258
# Total average test loss: 0.006346612909436226
# Model Saved!
#
# Time elapsed: 1001.5583038330078
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5835633962138485
# Current batch average train loss: 0.010527408681809902
#
# Current batch: 100
# Current batch average train accuracy: 0.5700519452897154
# Current batch average train loss: 0.011226771399378777
#
# Current batch: 200
# Current batch average train accuracy: 0.48238395188915095
# Current batch average train loss: 0.01207771897315979
#
# Current batch: 300
# Current batch average train accuracy: 0.45311754394325443
# Current batch average train loss: 0.011893685907125473
#
# Total average train accuarcy: 0.6289542669964973
# Total average train loss: 0.009591986538767815
#
# [ Test epoch: 15 ]
#
# Total average test accuarcy: 0.8286
# Total average test loss: 0.006145492041110992
# Model Saved!
#
# Time elapsed: 1068.3338332176208
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.62411356423882
# Current batch average train loss: 0.009960032999515533
#
# Current batch: 100
# Current batch average train accuracy: 0.6589189026023043
# Current batch average train loss: 0.009505560621619225
#
# Current batch: 200
# Current batch average train accuracy: 0.6410360826937959
# Current batch average train loss: 0.010046809911727905
#
# Current batch: 300
# Current batch average train accuracy: 0.5568481805690952
# Current batch average train loss: 0.010873585008084774
#
# Total average train accuarcy: 0.6363022077353924
# Total average train loss: 0.00947659525990486
#
# [ Test epoch: 16 ]
#
# Total average test accuarcy: 0.5892
# Total average test loss: 0.012428106665611267
# Model Saved!
#
# Time elapsed: 1135.0796415805817
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6846911468397897
# Current batch average train loss: 0.009270016103982925
#
# Current batch: 100
# Current batch average train accuracy: 0.6429751959752706
# Current batch average train loss: 0.010512473061680794
#
# Current batch: 200
# Current batch average train accuracy: 0.4676635350936079
# Current batch average train loss: 0.0124819315969944
#
# Current batch: 300
# Current batch average train accuracy: 0.7679416398782779
# Current batch average train loss: 0.007116319146007299
#
# Total average train accuarcy: 0.6420090803206528
# Total average train loss: 0.009280086843967437
#
# [ Test epoch: 17 ]
#
# Total average test accuarcy: 0.7824
# Total average test loss: 0.007538222736120224
# Model Saved!
#
# Time elapsed: 1201.8748149871826
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.43165684080955713
# Current batch average train loss: 0.012152612209320068
#
# Current batch: 100
# Current batch average train accuracy: 0.8488443348484067
# Current batch average train loss: 0.0050377147272229195
#
# Current batch: 200
# Current batch average train accuracy: 0.9159492446880936
# Current batch average train loss: 0.00324699142947793
#
# Current batch: 300
# Current batch average train accuracy: 0.4581778256837796
# Current batch average train loss: 0.012029880657792091
#
# Total average train accuarcy: 0.647494602942034
# Total average train loss: 0.009199973105192185
#
# [ Test epoch: 18 ]
#
# Total average test accuarcy: 0.8311
# Total average test loss: 0.0059277821749448775
# Model Saved!
#
# Time elapsed: 1268.725900888443
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8346932541687989
# Current batch average train loss: 0.005113417748361826
#
# Current batch: 100
# Current batch average train accuracy: 0.4506254012606849
# Current batch average train loss: 0.012803751043975353
#
# Current batch: 200
# Current batch average train accuracy: 0.44799732320628044
# Current batch average train loss: 0.012697161175310612
#
# Current batch: 300
# Current batch average train accuracy: 0.6973288156471262
# Current batch average train loss: 0.008738487958908081
#
# Total average train accuarcy: 0.6509038014124966
# Total average train loss: 0.009102683750987052
#
# [ Test epoch: 19 ]
#
# Total average test accuarcy: 0.8306
# Total average test loss: 0.006778233927488327
# Model Saved!
#
# Time elapsed: 1335.4485495090485
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.898280723774663
# Current batch average train loss: 0.003399990499019623
#
# Current batch: 100
# Current batch average train accuracy: 0.7103092676234783
# Current batch average train loss: 0.008968899957835674
#
# Current batch: 200
# Current batch average train accuracy: 0.5470970681956869
# Current batch average train loss: 0.011399061419069767
#
# Current batch: 300
# Current batch average train accuracy: 0.5320017611862657
# Current batch average train loss: 0.01147262379527092
#
# Total average train accuarcy: 0.6513210440523681
# Total average train loss: 0.00902064241528511
#
# [ Test epoch: 20 ]
#
# Total average test accuarcy: 0.8127
# Total average test loss: 0.006664279979467392
# Model Saved!
#
# Time elapsed: 1402.1581897735596
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7956980515751807
# Current batch average train loss: 0.007270255126059055
#
# Current batch: 100
# Current batch average train accuracy: 0.629545271031531
# Current batch average train loss: 0.010497888550162315
#
# Current batch: 200
# Current batch average train accuracy: 0.8386429675644214
# Current batch average train loss: 0.005098198540508747
#
# Current batch: 300
# Current batch average train accuracy: 0.6457638938643855
# Current batch average train loss: 0.009745929390192032
#
# Total average train accuarcy: 0.6575348683048398
# Total average train loss: 0.00896349011838436
#
# [ Test epoch: 21 ]
#
# Total average test accuarcy: 0.8414
# Total average test loss: 0.006261044952273369
# Model Saved!
#
# Time elapsed: 1468.8727297782898
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.46384330299620236
# Current batch average train loss: 0.012127810157835484
#
# Current batch: 100
# Current batch average train accuracy: 0.7979306609299194
# Current batch average train loss: 0.0075445654802024364
#
# Current batch: 200
# Current batch average train accuracy: 0.7261159493316512
# Current batch average train loss: 0.00808890163898468
#
# Current batch: 300
# Current batch average train accuracy: 0.7543846390862218
# Current batch average train loss: 0.007166791241616011
#
# Total average train accuarcy: 0.6532258498996741
# Total average train loss: 0.00899898140847683
#
# [ Test epoch: 22 ]
#
# Total average test accuarcy: 0.838
# Total average test loss: 0.0058350933969020845
# Model Saved!
#
# Time elapsed: 1535.5777490139008
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7269860163734699
# Current batch average train loss: 0.008125689812004566
#
# Current batch: 100
# Current batch average train accuracy: 0.5017049365766912
# Current batch average train loss: 0.011683549731969833
#
# Current batch: 200
# Current batch average train accuracy: 0.45302727580800883
# Current batch average train loss: 0.012422941625118256
#
# Current batch: 300
# Current batch average train accuracy: 0.7514680265645658
# Current batch average train loss: 0.00765919778496027
#
# Total average train accuarcy: 0.663082175015935
# Total average train loss: 0.008861536831855773
#
# [ Test epoch: 23 ]
#
# Total average test accuarcy: 0.8561
# Total average test loss: 0.005453757610917091
# Model Saved!
#
# Time elapsed: 1602.1969096660614
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.47177607929044063
# Current batch average train loss: 0.011977467685937881
#
# Current batch: 100
# Current batch average train accuracy: 0.5633844971878063
# Current batch average train loss: 0.010822728276252747
#
# Current batch: 200
# Current batch average train accuracy: 0.5666811078720171
# Current batch average train loss: 0.011279791593551636
#
# Current batch: 300
# Current batch average train accuracy: 0.4793268424237114
# Current batch average train loss: 0.011621497571468353
#
# Total average train accuarcy: 0.6618035902010581
# Total average train loss: 0.008859682623445988
#
# [ Test epoch: 24 ]
#
# Total average test accuarcy: 0.8329
# Total average test loss: 0.005717722365260124
# Model Saved!
#
# Time elapsed: 1668.8305308818817
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6933388487322891
# Current batch average train loss: 0.009028032422065735
#
# Current batch: 100
# Current batch average train accuracy: 0.6872286701849495
# Current batch average train loss: 0.009420320391654968
#
# Current batch: 200
# Current batch average train accuracy: 0.71293693631059
# Current batch average train loss: 0.008775110356509686
#
# Current batch: 300
# Current batch average train accuracy: 0.4977162671137317
# Current batch average train loss: 0.011494838632643223
#
# Total average train accuarcy: 0.6659379635582438
# Total average train loss: 0.008735618798136712
#
# [ Test epoch: 25 ]
#
# Total average test accuarcy: 0.8519
# Total average test loss: 0.005853263822197914
# Model Saved!
#
# Time elapsed: 1735.498155593872
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7011031580227624
# Current batch average train loss: 0.009294340386986732
#
# Current batch: 100
# Current batch average train accuracy: 0.915641986486814
# Current batch average train loss: 0.0028074542060494423
#
# Current batch: 200
# Current batch average train accuracy: 0.5964970056476318
# Current batch average train loss: 0.010516632348299026
#
# Current batch: 300
# Current batch average train accuracy: 0.4718175335698055
# Current batch average train loss: 0.012059276923537254
#
# Total average train accuarcy: 0.6678323516123751
# Total average train loss: 0.008715743318498134
#
# [ Test epoch: 26 ]
#
# Total average test accuarcy: 0.8645
# Total average test loss: 0.005319135111570358
# Model Saved!
#
# Time elapsed: 1802.1059529781342
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6398688849571917
# Current batch average train loss: 0.009183773770928383
#
# Current batch: 100
# Current batch average train accuracy: 0.5274312078218137
# Current batch average train loss: 0.01148809865117073
#
# Current batch: 200
# Current batch average train accuracy: 0.5811459221390647
# Current batch average train loss: 0.010221845470368862
#
# Current batch: 300
# Current batch average train accuracy: 0.5013338068227736
# Current batch average train loss: 0.011455388739705086
#
# Total average train accuarcy: 0.6743716362389861
# Total average train loss: 0.00853304839670658
#
# [ Test epoch: 27 ]
#
# Total average test accuarcy: 0.877
# Total average test loss: 0.005120088461041451
# Model Saved!
#
# Time elapsed: 1868.7951090335846
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8917988562999736
# Current batch average train loss: 0.00275985524058342
#
# Current batch: 100
# Current batch average train accuracy: 0.815544589922812
# Current batch average train loss: 0.0060636503621935844
#
# Current batch: 200
# Current batch average train accuracy: 0.4939505511384161
# Current batch average train loss: 0.011572461575269699
#
# Current batch: 300
# Current batch average train accuracy: 0.7888714805612589
# Current batch average train loss: 0.00700414227321744
#
# Total average train accuarcy: 0.6598595028821053
# Total average train loss: 0.008822096009254456
#
# [ Test epoch: 28 ]
#
# Total average test accuarcy: 0.8317
# Total average test loss: 0.006360125136375427
# Model Saved!
#
# Time elapsed: 1935.5764465332031
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6229876862009642
# Current batch average train loss: 0.010056693106889725
#
# Current batch: 100
# Current batch average train accuracy: 0.44017448586347796
# Current batch average train loss: 0.012165028601884842
#
# Current batch: 200
# Current batch average train accuracy: 0.8559505589707602
# Current batch average train loss: 0.004407638683915138
#
# Current batch: 300
# Current batch average train accuracy: 0.553806398626166
# Current batch average train loss: 0.011018798686563969
#
# Total average train accuarcy: 0.6645599100931403
# Total average train loss: 0.008716065537929535
#
# [ Test epoch: 29 ]
#
# Total average test accuarcy: 0.8412
# Total average test loss: 0.005587404736876488
# Model Saved!
#
# Time elapsed: 2002.2550179958344
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6366485880109689
# Current batch average train loss: 0.009647639468312263
#
# Current batch: 100
# Current batch average train accuracy: 0.528787624159565
# Current batch average train loss: 0.011113223619759083
#
# Current batch: 200
# Current batch average train accuracy: 0.8555446568552706
# Current batch average train loss: 0.004765222780406475
#
# Current batch: 300
# Current batch average train accuracy: 0.7936887576475703
# Current batch average train loss: 0.006534498184919357
#
# Total average train accuarcy: 0.6593543653102351
# Total average train loss: 0.008895319525003434
#
# [ Test epoch: 30 ]
#
# Total average test accuarcy: 0.8684
# Total average test loss: 0.00531060034930706
# Model Saved!
#
# Time elapsed: 2068.906121969223
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.684568905413718
# Current batch average train loss: 0.009050240740180016
#
# Current batch: 100
# Current batch average train accuracy: 0.6540552940591688
# Current batch average train loss: 0.009984098374843597
#
# Current batch: 200
# Current batch average train accuracy: 0.8100726793276973
# Current batch average train loss: 0.006465778686106205
#
# Current batch: 300
# Current batch average train accuracy: 0.7000888633326129
# Current batch average train loss: 0.008685395121574402
#
# Total average train accuarcy: 0.660054731454786
# Total average train loss: 0.008793933063745499
#
# [ Test epoch: 31 ]
#
# Total average test accuarcy: 0.8495
# Total average test loss: 0.005583206057548523
# Model Saved!
#
# Time elapsed: 2135.537894964218
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4730441199104881
# Current batch average train loss: 0.011640792712569237
#
# Current batch: 100
# Current batch average train accuracy: 0.6870936726058234
# Current batch average train loss: 0.009349048137664795
#
# Current batch: 200
# Current batch average train accuracy: 0.6684974698288417
# Current batch average train loss: 0.009480103850364685
#
# Current batch: 300
# Current batch average train accuracy: 0.8324228519144737
# Current batch average train loss: 0.005131757818162441
#
# Total average train accuarcy: 0.6709040877307717
# Total average train loss: 0.008610129036307335
#
# [ Test epoch: 32 ]
#
# Total average test accuarcy: 0.8711
# Total average test loss: 0.005338197913765907
# Model Saved!
#
# Time elapsed: 2202.172394514084
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4530240888578637
# Current batch average train loss: 0.011626087129116058
#
# Current batch: 100
# Current batch average train accuracy: 0.8800552861874017
# Current batch average train loss: 0.00407106988132
#
# Current batch: 200
# Current batch average train accuracy: 0.48488143354854607
# Current batch average train loss: 0.011149121448397636
#
# Current batch: 300
# Current batch average train accuracy: 0.4580845399162091
# Current batch average train loss: 0.011933820322155952
#
# Total average train accuarcy: 0.6743015213330519
# Total average train loss: 0.008512250373363495
#
# [ Test epoch: 33 ]
#
# Total average test accuarcy: 0.8372
# Total average test loss: 0.005775399196147919
# Model Saved!
#
# Time elapsed: 2268.902454853058
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6775880651896093
# Current batch average train loss: 0.00922697875648737
#
# Current batch: 100
# Current batch average train accuracy: 0.8279549848250699
# Current batch average train loss: 0.005392776802182198
#
# Current batch: 200
# Current batch average train accuracy: 0.8539039883428285
# Current batch average train loss: 0.004530223086476326
#
# Current batch: 300
# Current batch average train accuracy: 0.727580154732238
# Current batch average train loss: 0.00836425181478262
#
# Total average train accuarcy: 0.6801217419023574
# Total average train loss: 0.008388074015378952
#
# [ Test epoch: 34 ]
#
# Total average test accuarcy: 0.8447
# Total average test loss: 0.005946991041302681
# Model Saved!
#
# Time elapsed: 2335.5848903656006
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4334662923387265
# Current batch average train loss: 0.011864589527249336
#
# Current batch: 100
# Current batch average train accuracy: 0.49747368977111406
# Current batch average train loss: 0.010921305045485497
#
# Current batch: 200
# Current batch average train accuracy: 0.750390237136975
# Current batch average train loss: 0.007912173867225647
#
# Current batch: 300
# Current batch average train accuracy: 0.4832665037299569
# Current batch average train loss: 0.011338163167238235
#
# Total average train accuarcy: 0.6741509423218136
# Total average train loss: 0.00852151511490345
#
# [ Test epoch: 35 ]
#
# Total average test accuarcy: 0.831
# Total average test loss: 0.0062783164739608766
# Model Saved!
#
# Time elapsed: 2402.190535068512
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7685648833176411
# Current batch average train loss: 0.007856372743844986
#
# Current batch: 100
# Current batch average train accuracy: 0.5307735857095086
# Current batch average train loss: 0.011185949668288231
#
# Current batch: 200
# Current batch average train accuracy: 0.46772168597746
# Current batch average train loss: 0.011986695230007172
#
# Current batch: 300
# Current batch average train accuracy: 0.7202750275716955
# Current batch average train loss: 0.008751971647143364
#
# Total average train accuarcy: 0.6831500828984565
# Total average train loss: 0.00832975230485201
#
# [ Test epoch: 36 ]
#
# Total average test accuarcy: 0.8637
# Total average test loss: 0.0048351142078638075
# Model Saved!
#
# Time elapsed: 2468.80495429039
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5766940387602627
# Current batch average train loss: 0.010715015232563019
#
# Current batch: 100
# Current batch average train accuracy: 0.8943168140274625
# Current batch average train loss: 0.0029262942261993885
#
# Current batch: 200
# Current batch average train accuracy: 0.8629725336333648
# Current batch average train loss: 0.005027850158512592
#
# Current batch: 300
# Current batch average train accuracy: 0.6207971115803161
# Current batch average train loss: 0.010018367320299149
#
# Total average train accuarcy: 0.6746586383391763
# Total average train loss: 0.008522035039961339
#
# [ Test epoch: 37 ]
#
# Total average test accuarcy: 0.8599
# Total average test loss: 0.005414388549327851
# Model Saved!
#
# Time elapsed: 2535.5565876960754
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6198408969289528
# Current batch average train loss: 0.010008664801716805
#
# Current batch: 100
# Current batch average train accuracy: 0.5091580053711249
# Current batch average train loss: 0.011045306921005249
#
# Current batch: 200
# Current batch average train accuracy: 0.9037822083058137
# Current batch average train loss: 0.0030929017812013626
#
# Current batch: 300
# Current batch average train accuracy: 0.662058152787575
# Current batch average train loss: 0.009395085275173187
#
# Total average train accuarcy: 0.681429285877732
# Total average train loss: 0.008322735458016395
#
# [ Test epoch: 38 ]
#
# Total average test accuarcy: 0.8983
# Total average test loss: 0.004426748868823051
# Model Saved!
#
# Time elapsed: 2602.2542445659637
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6946440760172693
# Current batch average train loss: 0.008227678015828133
#
# Current batch: 100
# Current batch average train accuracy: 0.4687992499056513
# Current batch average train loss: 0.011899100616574287
#
# Current batch: 200
# Current batch average train accuracy: 0.4812201439553543
# Current batch average train loss: 0.011681312695145607
#
# Current batch: 300
# Current batch average train accuracy: 0.46974166092778896
# Current batch average train loss: 0.011829530820250511
#
# Total average train accuarcy: 0.6797294992427689
# Total average train loss: 0.008374669509530067
#
# [ Test epoch: 39 ]
#
# Total average test accuarcy: 0.876
# Total average test loss: 0.005242493844032288
# Model Saved!
#
# Time elapsed: 2668.9666080474854
#
# [ Train epoch: 40 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8815748249298908
# Current batch average train loss: 0.002911154879257083
#
# Current batch: 100
# Current batch average train accuracy: 0.5213392297556619
# Current batch average train loss: 0.011081069707870483
#
# Current batch: 200
# Current batch average train accuracy: 0.7602141897892822
# Current batch average train loss: 0.007113057188689709
#
# Current batch: 300
# Current batch average train accuracy: 0.8731965369319901
# Current batch average train loss: 0.0039305612444877625
#
# Total average train accuarcy: 0.683428480660251
# Total average train loss: 0.008326469027996063
#
# [ Test epoch: 40 ]
#
# Total average test accuarcy: 0.8629
# Total average test loss: 0.005021289804577827
# Model Saved!
#
# Time elapsed: 2735.6902849674225
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9121341421294615
# Current batch average train loss: 0.002847321331501007
#
# Current batch: 100
# Current batch average train accuracy: 0.8362939533736407
# Current batch average train loss: 0.005675068590790033
#
# Current batch: 200
# Current batch average train accuracy: 0.6051069182072594
# Current batch average train loss: 0.010086428374052048
#
# Current batch: 300
# Current batch average train accuracy: 0.4833856965115213
# Current batch average train loss: 0.011523669585585594
#
# Total average train accuarcy: 0.6875878256959308
# Total average train loss: 0.008290350330471992
#
# [ Test epoch: 41 ]
#
# Total average test accuarcy: 0.8757
# Total average test loss: 0.0051241527140140535
# Model Saved!
#
# Time elapsed: 2802.3358495235443
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9157529735225616
# Current batch average train loss: 0.0024140344467014074
#
# Current batch: 100
# Current batch average train accuracy: 0.6936752039544061
# Current batch average train loss: 0.009359728544950485
#
# Current batch: 200
# Current batch average train accuracy: 0.5874551151569289
# Current batch average train loss: 0.010567942634224892
#
# Current batch: 300
# Current batch average train accuracy: 0.5267579660726087
# Current batch average train loss: 0.010949188843369484
#
# Total average train accuarcy: 0.6828420358094331
# Total average train loss: 0.008369768366813659
#
# [ Test epoch: 42 ]
#
# Total average test accuarcy: 0.8371
# Total average test loss: 0.005998759976029396
# Model Saved!
#
# Time elapsed: 2869.0548717975616
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.47387631710757505
# Current batch average train loss: 0.011513916775584221
#
# Current batch: 100
# Current batch average train accuracy: 0.517060626861549
# Current batch average train loss: 0.011014432646334171
#
# Current batch: 200
# Current batch average train accuracy: 0.7959555224012025
# Current batch average train loss: 0.006832574959844351
#
# Current batch: 300
# Current batch average train accuracy: 0.8051613299833656
# Current batch average train loss: 0.005662637762725353
#
# Total average train accuarcy: 0.6734177142685591
# Total average train loss: 0.00852047960549593
#
# [ Test epoch: 43 ]
#
# Total average test accuarcy: 0.8767
# Total average test loss: 0.005233234611153602
# Model Saved!
#
# Time elapsed: 2935.767889022827
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8189646439542708
# Current batch average train loss: 0.006205833982676268
#
# Current batch: 100
# Current batch average train accuracy: 0.7137831275187042
# Current batch average train loss: 0.008693449199199677
#
# Current batch: 200
# Current batch average train accuracy: 0.8540674592124122
# Current batch average train loss: 0.004845877178013325
#
# Current batch: 300
# Current batch average train accuracy: 0.841084821063723
# Current batch average train loss: 0.005430436693131924
#
# Total average train accuarcy: 0.6835716827551501
# Total average train loss: 0.008328581900000572
#
# [ Test epoch: 44 ]
#
# Total average test accuarcy: 0.8597
# Total average test loss: 0.006120356187224388
# Model Saved!
#
# Time elapsed: 3002.4674360752106
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.783160685188873
# Current batch average train loss: 0.0066551403142511845
#
# Current batch: 100
# Current batch average train accuracy: 0.5503490077026221
# Current batch average train loss: 0.01088156271725893
#
# Current batch: 200
# Current batch average train accuracy: 0.9024807042580507
# Current batch average train loss: 0.0038411468267440796
#
# Current batch: 300
# Current batch average train accuracy: 0.47859291574676677
# Current batch average train loss: 0.01174766756594181
#
# Total average train accuarcy: 0.6770095043079147
# Total average train loss: 0.008423923670649529
#
# [ Test epoch: 45 ]
#
# Total average test accuarcy: 0.8691
# Total average test loss: 0.005500601416826248
# Model Saved!
#
# Time elapsed: 3069.125997066498
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8930277794979897
# Current batch average train loss: 0.004321272484958172
#
# Current batch: 100
# Current batch average train accuracy: 0.614826719474508
# Current batch average train loss: 0.009956371039152145
#
# Current batch: 200
# Current batch average train accuracy: 0.8058003034363327
# Current batch average train loss: 0.006585187744349241
#
# Current batch: 300
# Current batch average train accuracy: 0.7966564002240295
# Current batch average train loss: 0.006579669192433357
#
# Total average train accuarcy: 0.679889596993066
# Total average train loss: 0.008344020285010337
#
# [ Test epoch: 46 ]
#
# Total average test accuarcy: 0.8663
# Total average test loss: 0.0052543422907590865
# Model Saved!
#
# Time elapsed: 3135.804318666458
#
# [ Train epoch: 47 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6867426027263351
# Current batch average train loss: 0.008776665665209293
#
# Current batch: 100
# Current batch average train accuracy: 0.5650137728173157
# Current batch average train loss: 0.01027723029255867
#
# Current batch: 200
# Current batch average train accuracy: 0.7577945293085457
# Current batch average train loss: 0.007402485236525536
#
# Current batch: 300
# Current batch average train accuracy: 0.8339208036577469
# Current batch average train loss: 0.005249808542430401
#
# Total average train accuarcy: 0.6799115203210567
# Total average train loss: 0.008349093192517757
#
# [ Test epoch: 47 ]
#
# Total average test accuarcy: 0.8989
# Total average test loss: 0.004416780793666839
# Model Saved!
#
# Time elapsed: 3202.499906539917
#
# [ Train epoch: 48 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6991706109057686
# Current batch average train loss: 0.00906429160386324
#
# Current batch: 100
# Current batch average train accuracy: 0.607942983861404
# Current batch average train loss: 0.009683240205049515
#
# Current batch: 200
# Current batch average train accuracy: 0.9121239329813606
# Current batch average train loss: 0.003158584237098694
#
# Current batch: 300
# Current batch average train accuracy: 0.7300936188118036
# Current batch average train loss: 0.008352287113666534
#
# Total average train accuarcy: 0.6829816512276664
# Total average train loss: 0.008254536771476268
#
# [ Test epoch: 48 ]
#
# Total average test accuarcy: 0.8789
# Total average test loss: 0.00466936005949974
# Model Saved!
#
# Time elapsed: 3269.265241384506
#
# [ Train epoch: 49 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6067292503339063
# Current batch average train loss: 0.010380035266280174
#
# Current batch: 100
# Current batch average train accuracy: 0.4770109486781782
# Current batch average train loss: 0.011313151568174362
#
# Current batch: 200
# Current batch average train accuracy: 0.7006078222025547
# Current batch average train loss: 0.008936317637562752
#
# Current batch: 300
# Current batch average train accuracy: 0.538241378894661
# Current batch average train loss: 0.010917304083704948
#
# Total average train accuarcy: 0.6753781486814575
# Total average train loss: 0.008381831959784031
#
# [ Test epoch: 49 ]
#
# Total average test accuarcy: 0.8704
# Total average test loss: 0.005301376989483833
# Model Saved!
#
# Time elapsed: 3335.917849302292
#
# [ Train epoch: 50 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7276304031811708
# Current batch average train loss: 0.008241027593612671
#
# Current batch: 100
# Current batch average train accuracy: 0.4991619345196936
# Current batch average train loss: 0.010837003588676453
#
# Current batch: 200
# Current batch average train accuracy: 0.4843864023376577
# Current batch average train loss: 0.011086360551416874
#
# Current batch: 300
# Current batch average train accuracy: 0.8704111370074492
# Current batch average train loss: 0.00517859123647213
#
# Total average train accuarcy: 0.7201921637639677
# Total average train loss: 0.00740821939945221
#
# [ Test epoch: 50 ]
#
# Total average test accuarcy: 0.9322
# Total average test loss: 0.0033998285084962843
# Model Saved!
#
# Time elapsed: 3402.5712461471558
#
# [ Train epoch: 51 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7967076312471324
# Current batch average train loss: 0.006498061586171389
#
# Current batch: 100
# Current batch average train accuracy: 0.8785964286080938
# Current batch average train loss: 0.004705853294581175
#
# Current batch: 200
# Current batch average train accuracy: 0.5245981799860285
# Current batch average train loss: 0.010474528186023235
#
# Current batch: 300
# Current batch average train accuracy: 0.5762519959697323
# Current batch average train loss: 0.010061219334602356
#
# Total average train accuarcy: 0.7206051040815805
# Total average train loss: 0.007242778364121914
#
# [ Test epoch: 51 ]
#
# Total average test accuarcy: 0.933
# Total average test loss: 0.003268126158416271
# Model Saved!
#
# Time elapsed: 3469.2342245578766
#
# [ Train epoch: 52 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9302811686998594
# Current batch average train loss: 0.0030899574048817158
#
# Current batch: 100
# Current batch average train accuracy: 0.5821017436123366
# Current batch average train loss: 0.009113042615354061
#
# Current batch: 200
# Current batch average train accuracy: 0.6666674260849728
# Current batch average train loss: 0.00854538194835186
#
# Current batch: 300
# Current batch average train accuracy: 0.513304677180158
# Current batch average train loss: 0.010574189946055412
#
# Total average train accuarcy: 0.7109039085324957
# Total average train loss: 0.007352837774008513
#
# [ Test epoch: 52 ]
#
# Total average test accuarcy: 0.9337
# Total average test loss: 0.0035174703180789945
# Model Saved!
#
# Time elapsed: 3535.943140029907
#
# [ Train epoch: 53 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7010417908880129
# Current batch average train loss: 0.008676037192344666
#
# Current batch: 100
# Current batch average train accuracy: 0.8368512062028022
# Current batch average train loss: 0.005838170647621155
#
# Current batch: 200
# Current batch average train accuracy: 0.6234633640157815
# Current batch average train loss: 0.009393150918185711
#
# Current batch: 300
# Current batch average train accuracy: 0.7911572743996766
# Current batch average train loss: 0.0066809868440032005
#
# Total average train accuarcy: 0.7166088648277975
# Total average train loss: 0.007284687030613422
#
# [ Test epoch: 53 ]
#
# Total average test accuarcy: 0.9346
# Total average test loss: 0.003550024935603142
# Model Saved!
#
# Time elapsed: 3602.683805704117
#
# [ Train epoch: 54 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6786496132228483
# Current batch average train loss: 0.008888423442840576
#
# Current batch: 100
# Current batch average train accuracy: 0.6702501386032876
# Current batch average train loss: 0.008535055443644524
#
# Current batch: 200
# Current batch average train accuracy: 0.5999170274417723
# Current batch average train loss: 0.009140970185399055
#
# Current batch: 300
# Current batch average train accuracy: 0.5143876811216189
# Current batch average train loss: 0.009674591943621635
#
# Total average train accuarcy: 0.7248821795598128
# Total average train loss: 0.007129936498254537
#
# [ Test epoch: 54 ]
#
# Total average test accuarcy: 0.9359
# Total average test loss: 0.0032155083656311037
# Model Saved!
#
# Time elapsed: 3669.3814957141876
#
# [ Train epoch: 55 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8794902622562397
# Current batch average train loss: 0.00438122171908617
#
# Current batch: 100
# Current batch average train accuracy: 0.6320044059958078
# Current batch average train loss: 0.008980495855212212
#
# Current batch: 200
# Current batch average train accuracy: 0.6209772907950384
# Current batch average train loss: 0.009358863346278667
#
# Current batch: 300
# Current batch average train accuracy: 0.7236341133440269
# Current batch average train loss: 0.007942304946482182
#
# Total average train accuarcy: 0.7339772242596636
# Total average train loss: 0.00690801213234663
#
# [ Test epoch: 55 ]
#
# Total average test accuarcy: 0.9405
# Total average test loss: 0.0028638071775436403
# Model Saved!
#
# Time elapsed: 3736.017774105072
#
# [ Train epoch: 56 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9457271134946532
# Current batch average train loss: 0.0023267664946615696
#
# Current batch: 100
# Current batch average train accuracy: 0.8742522622014406
# Current batch average train loss: 0.005005291197448969
#
# Current batch: 200
# Current batch average train accuracy: 0.6557789119860252
# Current batch average train loss: 0.008634164929389954
#
# Current batch: 300
# Current batch average train accuracy: 0.7893796407288208
# Current batch average train loss: 0.006629012059420347
#
# Total average train accuarcy: 0.7289888632998855
# Total average train loss: 0.007017364498823881
#
# [ Test epoch: 56 ]
#
# Total average test accuarcy: 0.9393
# Total average test loss: 0.002976816096901894
# Model Saved!
#
# Time elapsed: 3802.6953189373016
#
# [ Train epoch: 57 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8127712163113752
# Current batch average train loss: 0.0062951394356787205
#
# Current batch: 100
# Current batch average train accuracy: 0.750853335754852
# Current batch average train loss: 0.007135809399187565
#
# Current batch: 200
# Current batch average train accuracy: 0.8570132832169489
# Current batch average train loss: 0.00516480440273881
#
# Current batch: 300
# Current batch average train accuracy: 0.7478893353823232
# Current batch average train loss: 0.007527969777584076
#
# Total average train accuarcy: 0.7343727799437023
# Total average train loss: 0.006913964761942625
#
# [ Test epoch: 57 ]
#
# Total average test accuarcy: 0.939
# Total average test loss: 0.002946750469505787
# Model Saved!
#
# Time elapsed: 3869.316492319107
#
# [ Train epoch: 58 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5087449909666316
# Current batch average train loss: 0.009836666285991669
#
# Current batch: 100
# Current batch average train accuracy: 0.9510652397897964
# Current batch average train loss: 0.002097643679007888
#
# Current batch: 200
# Current batch average train accuracy: 0.9741583288642068
# Current batch average train loss: 0.0016452341806143522
#
# Current batch: 300
# Current batch average train accuracy: 0.5613730017511439
# Current batch average train loss: 0.00997716374695301
#
# Total average train accuarcy: 0.7156082789270637
# Total average train loss: 0.007100790060162544
#
# [ Test epoch: 58 ]
#
# Total average test accuarcy: 0.9381
# Total average test loss: 0.0033378781497478485
# Model Saved!
#
# Time elapsed: 3935.974833726883
#
# [ Train epoch: 59 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9312836420974626
# Current batch average train loss: 0.0027957085985690355
#
# Current batch: 100
# Current batch average train accuracy: 0.9344946100736446
# Current batch average train loss: 0.0031232936307787895
#
# Current batch: 200
# Current batch average train accuracy: 0.657352435599697
# Current batch average train loss: 0.008465033024549484
#
# Current batch: 300
# Current batch average train accuracy: 0.8224275581730146
# Current batch average train loss: 0.005843407474458218
#
# Total average train accuarcy: 0.730031682710888
# Total average train loss: 0.006968112013339996
#
# [ Test epoch: 59 ]
#
# Total average test accuarcy: 0.9438
# Total average test loss: 0.003419049343466759
# Model Saved!
#
# Time elapsed: 4002.7574486732483
#
# [ Train epoch: 60 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9804424752923733
# Current batch average train loss: 0.0008797087939456105
#
# Current batch: 100
# Current batch average train accuracy: 0.5437730250887853
# Current batch average train loss: 0.009051199071109295
#
# Current batch: 200
# Current batch average train accuracy: 0.724932197204623
# Current batch average train loss: 0.007595373783260584
#
# Current batch: 300
# ...
# Total average test loss: 0.0031957252129912374
# Model Saved!
#
# Time elapsed: 8646.045272111893
#
# [ Train epoch: 130 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5442481598990595
# Current batch average train loss: 0.008848476223647594
#
# Current batch: 100
# Current batch average train accuracy: 0.9169803326501212
# Current batch average train loss: 0.0032301375176757574
#
# Current batch: 200
# Current batch average train accuracy: 0.94304479140222
# Current batch average train loss: 0.002426121849566698
#
# Current batch: 300
# Current batch average train accuracy: 0.9509357794039116
# Current batch average train loss: 0.002335348166525364
#
# Total average train accuarcy: 0.746428161079196
# Total average train loss: 0.00604819926854223
#
# [ Test epoch: 130 ]
#
# Total average test accuarcy: 0.9532
# Total average test loss: 0.0025860791847109794
# Model Saved!
#
# Time elapsed: 8712.659524917603
#
# [ Train epoch: 131 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5413990800571664
# Current batch average train loss: 0.008358323946595192
#
# Current batch: 100
# Current batch average train accuracy: 0.956322021151292
# Current batch average train loss: 0.0021785509306937456
#
# Current batch: 200
# Current batch average train accuracy: 0.5907772503074985
# Current batch average train loss: 0.00844735186547041
#
# Current batch: 300
# Current batch average train accuracy: 0.7116155570041771
# Current batch average train loss: 0.0074927848763763905
#
# Total average train accuarcy: 0.7563301582939699
# Total average train loss: 0.005937764856442809
#
# [ Test epoch: 131 ]
#
# Total average test accuarcy: 0.9531
# Total average test loss: 0.002493822033703327
# Model Saved!
#
# Time elapsed: 8779.292255163193
#
# [ Train epoch: 132 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8984641333707069
# Current batch average train loss: 0.004134226590394974
#
# Current batch: 100
# Current batch average train accuracy: 0.8585331749113211
# Current batch average train loss: 0.005302480421960354
#
# Current batch: 200
# Current batch average train accuracy: 0.7769329932465568
# Current batch average train loss: 0.0063219559378921986
#
# Current batch: 300
# Current batch average train accuracy: 0.724882884197696
# Current batch average train loss: 0.0071363747119903564
#
# Total average train accuarcy: 0.7470294946025022
# Total average train loss: 0.0061205947940796614
#
# [ Test epoch: 132 ]
#
# Total average test accuarcy: 0.9528
# Total average test loss: 0.002938533814251423
# Model Saved!
#
# Time elapsed: 8845.91752409935
#
# [ Train epoch: 133 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7678124920089435
# Current batch average train loss: 0.006644732318818569
#
# Current batch: 100
# Current batch average train accuracy: 0.5466054307635557
# Current batch average train loss: 0.008087343536317348
#
# Current batch: 200
# Current batch average train accuracy: 0.7877951544434728
# Current batch average train loss: 0.006331080570816994
#
# Current batch: 300
# Current batch average train accuracy: 0.935113606689405
# Current batch average train loss: 0.0028743622824549675
#
# Total average train accuarcy: 0.7514055293740647
# Total average train loss: 0.006026260542422533
#
# [ Test epoch: 133 ]
#
# Total average test accuarcy: 0.953
# Total average test loss: 0.0029216033235192297
# Model Saved!
#
# Time elapsed: 8912.60617852211
#
# [ Train epoch: 134 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6783164065721184
# Current batch average train loss: 0.00768596027046442
#
# Current batch: 100
# Current batch average train accuracy: 0.6686835267894
# Current batch average train loss: 0.007500690408051014
#
# Current batch: 200
# Current batch average train accuracy: 0.5983820954879223
# Current batch average train loss: 0.007983719930052757
#
# Current batch: 300
# Current batch average train accuracy: 0.7872343975964687
# Current batch average train loss: 0.006140599027276039
#
# Total average train accuarcy: 0.7438843355197906
# Total average train loss: 0.006116365013867617
#
# [ Test epoch: 134 ]
#
# Total average test accuarcy: 0.9526
# Total average test loss: 0.002945244450867176
# Model Saved!
#
# Time elapsed: 8979.25099158287
#
# [ Train epoch: 135 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6329300677079013
# Current batch average train loss: 0.007910724729299545
#
# Current batch: 100
# Current batch average train accuracy: 0.5200439749182051
# Current batch average train loss: 0.009058116935193539
#
# Current batch: 200
# Current batch average train accuracy: 0.7689259532816634
# Current batch average train loss: 0.006647923029959202
#
# Current batch: 300
# Current batch average train accuracy: 0.8668103552867101
# Current batch average train loss: 0.004676558542996645
#
# Total average train accuarcy: 0.7409928375161335
# Total average train loss: 0.006117847642377019
#
# [ Test epoch: 135 ]
#
# Total average test accuarcy: 0.9522
# Total average test loss: 0.0029027828857302665
# Model Saved!
#
# Time elapsed: 9046.07349228859
#
# [ Train epoch: 136 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.860617922648633
# Current batch average train loss: 0.004971373826265335
#
# Current batch: 100
# Current batch average train accuracy: 0.7180509273623147
# Current batch average train loss: 0.006833603139966726
#
# Current batch: 200
# Current batch average train accuracy: 0.717422455278022
# Current batch average train loss: 0.007058289833366871
#
# Current batch: 300
# Current batch average train accuracy: 0.5516790391148719
# Current batch average train loss: 0.008449602872133255
#
# Total average train accuarcy: 0.7564354400943365
# Total average train loss: 0.006003295298069715
#
# [ Test epoch: 136 ]
#
# Total average test accuarcy: 0.9535
# Total average test loss: 0.002650741447508335
# Model Saved!
#
# Time elapsed: 9112.7358148098
#
# [ Train epoch: 137 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7810224987425585
# Current batch average train loss: 0.0064147356897592545
#
# Current batch: 100
# Current batch average train accuracy: 0.7750881305987549
# Current batch average train loss: 0.00613387580960989
#
# Current batch: 200
# Current batch average train accuracy: 0.9554430132661693
# Current batch average train loss: 0.0022429167293012142
#
# Current batch: 300
# Current batch average train accuracy: 0.5520064658187861
# Current batch average train loss: 0.00859769992530346
#
# Total average train accuarcy: 0.7404442087823601
# Total average train loss: 0.006195183066800236
#
# [ Test epoch: 137 ]
#
# Total average test accuarcy: 0.9535
# Total average test loss: 0.0026744714483618735
# Model Saved!
#
# Time elapsed: 9179.48655295372
#
# [ Train epoch: 138 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5985659125762142
# Current batch average train loss: 0.007959694601595402
#
# Current batch: 100
# Current batch average train accuracy: 0.7776410585752564
# Current batch average train loss: 0.006395172327756882
#
# Current batch: 200
# Current batch average train accuracy: 0.5372747651727188
# Current batch average train loss: 0.009116023778915405
#
# Current batch: 300
# Current batch average train accuracy: 0.5479915754339453
# Current batch average train loss: 0.008396386168897152
#
# Total average train accuarcy: 0.7547118403482264
# Total average train loss: 0.005954013207033276
#
# [ Test epoch: 138 ]
#
# Total average test accuarcy: 0.952
# Total average test loss: 0.002635079325735569
# Model Saved!
#
# Time elapsed: 9246.147990226746
#
# [ Train epoch: 139 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6538900318313349
# Current batch average train loss: 0.0071573578752577305
#
# Current batch: 100
# Current batch average train accuracy: 0.7033008359960558
# Current batch average train loss: 0.0074406573548913
#
# Current batch: 200
# Current batch average train accuracy: 0.9361238818904869
# Current batch average train loss: 0.0027207687962800264
#
# Current batch: 300
# Current batch average train accuracy: 0.6369820303310806
# Current batch average train loss: 0.008345909416675568
#
# Total average train accuarcy: 0.747290446968142
# Total average train loss: 0.006105197785273194
#
# [ Test epoch: 139 ]
#
# Total average test accuarcy: 0.9508
# Total average test loss: 0.0028653071850538252
# Model Saved!
#
# Time elapsed: 9312.804832696915
#
# [ Train epoch: 140 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6794079727566017
# Current batch average train loss: 0.007779297418892384
#
# Current batch: 100
# Current batch average train accuracy: 0.8794792707986816
# Current batch average train loss: 0.004566481802612543
#
# Current batch: 200
# Current batch average train accuracy: 0.7284131337515117
# Current batch average train loss: 0.0070243338122963905
#
# Current batch: 300
# Current batch average train accuracy: 0.9616660237783056
# Current batch average train loss: 0.001980121247470379
#
# Total average train accuarcy: 0.7496489429218679
# Total average train loss: 0.006023180984295905
#
# [ Test epoch: 140 ]
#
# Total average test accuarcy: 0.9536
# Total average test loss: 0.002617117723822594
# Model Saved!
#
# Time elapsed: 9379.543452501297
#
# [ Train epoch: 141 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9345391882828066
# Current batch average train loss: 0.00296501605771482
#
# Current batch: 100
# Current batch average train accuracy: 0.6050864815205519
# Current batch average train loss: 0.00864104088395834
#
# Current batch: 200
# Current batch average train accuracy: 0.8109393027264415
# Current batch average train loss: 0.005824475083500147
#
# Current batch: 300
# Current batch average train accuracy: 0.9638222966352612
# Current batch average train loss: 0.001828448730520904
#
# Total average train accuarcy: 0.7492463498807977
# Total average train loss: 0.006067967097982764
#
# [ Test epoch: 141 ]
#
# Total average test accuarcy: 0.9541
# Total average test loss: 0.0025662574753165246
# Model Saved!
#
# Time elapsed: 9446.325755357742
#
# [ Train epoch: 142 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.527436760432137
# Current batch average train loss: 0.00889892503619194
#
# Current batch: 100
# Current batch average train accuracy: 0.9447276336149686
# Current batch average train loss: 0.0025746971368789673
#
# Current batch: 200
# Current batch average train accuracy: 0.5661979351195163
# Current batch average train loss: 0.00880567729473114
#
# Current batch: 300
# Current batch average train accuracy: 0.6822092261369768
# Current batch average train loss: 0.007508397102355957
#
# Total average train accuarcy: 0.7509354651287371
# Total average train loss: 0.006025887894034385
#
# [ Test epoch: 142 ]
#
# Total average test accuarcy: 0.9532
# Total average test loss: 0.0024765399888157843
# Model Saved!
#
# Time elapsed: 9512.990323781967
#
# [ Train epoch: 143 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7683568483088205
# Current batch average train loss: 0.006294972263276577
#
# Current batch: 100
# Current batch average train accuracy: 0.5011322142364562
# Current batch average train loss: 0.0087303277105093
#
# Current batch: 200
# Current batch average train accuracy: 0.7708024344193449
# Current batch average train loss: 0.00682255532592535
#
# Current batch: 300
# Current batch average train accuracy: 0.9054261070998907
# Current batch average train loss: 0.0038714995607733727
#
# Total average train accuarcy: 0.7476717365530599
# Total average train loss: 0.006131281115338207
#
# [ Test epoch: 143 ]
#
# Total average test accuarcy: 0.9513
# Total average test loss: 0.003031850178539753
# Model Saved!
#
# Time elapsed: 9579.680274963379
#
# [ Train epoch: 144 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8296020494011249
# Current batch average train loss: 0.0057301996275782585
#
# Current batch: 100
# Current batch average train accuracy: 0.5682416466713484
# Current batch average train loss: 0.008266473188996315
#
# Current batch: 200
# Current batch average train accuracy: 0.6181851929673581
# Current batch average train loss: 0.00843857042491436
#
# Current batch: 300
# Current batch average train accuracy: 0.8868391194122114
# Current batch average train loss: 0.0041803028434515
#
# Total average train accuarcy: 0.7449068315153389
# Total average train loss: 0.006116017061546445
#
# [ Test epoch: 144 ]
#
# Total average test accuarcy: 0.9541
# Total average test loss: 0.0025335115909576418
# Model Saved!
#
# Time elapsed: 9646.310395479202
#
# [ Train epoch: 145 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5211583075094316
# Current batch average train loss: 0.009316116571426392
#
# Current batch: 100
# Current batch average train accuracy: 0.5331238776698377
# Current batch average train loss: 0.008051423355937004
#
# Current batch: 200
# Current batch average train accuracy: 0.632779709722093
# Current batch average train loss: 0.008118171244859695
#
# Current batch: 300
# Current batch average train accuracy: 0.6243486504231693
# Current batch average train loss: 0.00780374463647604
#
# Total average train accuarcy: 0.7409868613995293
# Total average train loss: 0.0061375677863508464
#
# [ Test epoch: 145 ]
#
# Total average test accuarcy: 0.9505
# Total average test loss: 0.003069488602876663
# Model Saved!
#
# Time elapsed: 9712.948507070541
#
# [ Train epoch: 146 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7687958369475167
# Current batch average train loss: 0.006505269091576338
#
# Current batch: 100
# Current batch average train accuracy: 0.5529752154135832
# Current batch average train loss: 0.0077898851595819
#
# Current batch: 200
# Current batch average train accuracy: 0.970796238099817
# Current batch average train loss: 0.0015766455326229334
#
# Current batch: 300
# Current batch average train accuracy: 0.8601890510743495
# Current batch average train loss: 0.004896251484751701
#
# Total average train accuarcy: 0.7560246099159315
# Total average train loss: 0.00587197659470141
#
# [ Test epoch: 146 ]
#
# Total average test accuarcy: 0.9538
# Total average test loss: 0.0026357221022248268
# Model Saved!
#
# Time elapsed: 9779.536874771118
#
# [ Train epoch: 147 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8594105202421427
# Current batch average train loss: 0.004945642780512571
#
# Current batch: 100
# Current batch average train accuracy: 0.5965230241244993
# Current batch average train loss: 0.007827886380255222
#
# Current batch: 200
# Current batch average train accuracy: 0.524576217783617
# Current batch average train loss: 0.008433989249169827
#
# Current batch: 300
# Current batch average train accuracy: 0.9636562102862775
# Current batch average train loss: 0.0018428826006129384
#
# Total average train accuarcy: 0.7454357309142124
# Total average train loss: 0.006047750010192394
#
# [ Test epoch: 147 ]
#
# Total average test accuarcy: 0.9513
# Total average test loss: 0.00304481540620327
# Model Saved!
#
# Time elapsed: 9846.158405780792
#
# [ Train epoch: 148 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8864145103888409
# Current batch average train loss: 0.004352896008640528
#
# Current batch: 100
# Current batch average train accuracy: 0.5477616335484129
# Current batch average train loss: 0.008756900206208229
#
# Current batch: 200
# Current batch average train accuracy: 0.8546245614474951
# Current batch average train loss: 0.004943473264575005
#
# Current batch: 300
# Current batch average train accuracy: 0.7319637626906885
# Current batch average train loss: 0.006734293885529041
#
# Total average train accuarcy: 0.7451659917878135
# Total average train loss: 0.006065206831246614
#
# [ Test epoch: 148 ]
#
# Total average test accuarcy: 0.9547
# Total average test loss: 0.002566776989400387
# Model Saved!
#
# Time elapsed: 9912.74497294426
#
# [ Train epoch: 149 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.666153996821432
# Current batch average train loss: 0.007791293319314718
#
# Current batch: 100
# Current batch average train accuracy: 0.9209611248679173
# Current batch average train loss: 0.003350219689309597
#
# Current batch: 200
# Current batch average train accuracy: 0.9960419099991833
# Current batch average train loss: 0.0003982539055868983
#
# Current batch: 300
# Current batch average train accuracy: 0.9107526108495387
# Current batch average train loss: 0.0036425888538360596
#
# Total average train accuarcy: 0.7550751687327749
# Total average train loss: 0.005944291359558701
#
# [ Test epoch: 149 ]
#
# Total average test accuarcy: 0.9533
# Total average test loss: 0.0025830017626285555
# Model Saved!
#
# Time elapsed: 9979.339742422104
