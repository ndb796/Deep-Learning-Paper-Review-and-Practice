# %% [markdown]
# <a href="https://colab.research.google.com/github/ndb796/Deep-Learning-Paper-Review-and-Practice/blob/master/ResNet18_CIFAR10_Training_with_Input_Mixup_and_Label_Smoothing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### <b>ResNet18 모델 아키텍처 정의</b>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out) # 출력: [batch_size, 512, 4, 4]
        out = F.avg_pool2d(out, 4) # 출력: [batch_size, 512, 1, 1]
        out = out.view(out.size(0), -1) # 출력: [batch_size, 512]
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### <b>데이터셋(Dataset) 다운로드 및 불러오기</b>

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# #### <b>필요한 라이브러리 구현</b>

# %%
import numpy as np

mixup_alpha = 1.0

def mixup_data(x, y):
    lam = np.random.beta(mixup_alpha, mixup_alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()
    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)


class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self):
        super(LabelSmoothingCrossEntropy, self).__init__()
    def forward(self, y, targets, smoothing=0.1):
        confidence = 1. - smoothing
        log_probs = F.log_softmax(y, dim=-1) # 예측 확률 계산
        true_probs = torch.zeros_like(log_probs)
        true_probs.fill_(smoothing / (y.shape[1] - 1))
        true_probs.scatter_(1, targets.data.unsqueeze(1), confidence) # 정답 인덱스의 정답 확률을 confidence로 변경
        return torch.mean(torch.sum(true_probs * -log_probs, dim=-1)) # negative log likelihood

# %% [markdown]
# #### <b>환경 설정 및 학습(Training) 함수 정의</b>

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)

learning_rate = 0.1
file_name = 'resnet18_cifar10.pth'

criterion = LabelSmoothingCrossEntropy()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets)
        optimizer.zero_grad()

        outputs = net(inputs)
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        current_correct = (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())
        correct += current_correct

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current batch average train accuracy:', current_correct / targets.size(0))
            print('Current batch average train loss:', loss.item() / targets.size(0))

    print('\nTotal average train accuarcy:', correct / total)
    print('Total average train loss:', train_loss / total)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTotal average test accuarcy:', correct / total)
    print('Total average test loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %% [markdown]
# #### <b>학습(Training) 진행</b>

# %%
import time


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 50:
        lr /= 10
    if epoch >= 100:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

start_time = time.time()

for epoch in range(0, 150):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
    print('\nTime elapsed:', time.time() - start_time)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.0676012122688769
# Current batch average train loss: 0.018984787166118622
#
# Current batch: 100
# Current batch average train accuracy: 0.186298824527742
# Current batch average train loss: 0.01728200539946556
#
# Current batch: 200
# Current batch average train accuracy: 0.3010016673709568
# Current batch average train loss: 0.0157657228410244
#
# Current batch: 300
# Current batch average train accuracy: 0.36779025048328734
# Current batch average train loss: 0.015063154511153698
#
# Total average train accuarcy: 0.24367330731643452
# Total average train loss: 0.016990246500968934
#
# [ Test epoch: 0 ]
#
# Total average test accuarcy: 0.3424
# Total average test loss: 0.01910388306379318
# Model Saved!
#
# Time elapsed: 62.836387157440186
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.42075508090404934
# Current batch average train loss: 0.01484421081840992
#
# Current batch: 100
# Current batch average train accuracy: 0.3048462339166179
# Current batch average train loss: 0.015838202089071274
#
# Current batch: 200
# Current batch average train accuracy: 0.3217610598301948
# Current batch average train loss: 0.01561430562287569
#
# Current batch: 300
# Current batch average train accuracy: 0.359907188789915
# Current batch average train loss: 0.015489274635910988
#
# Total average train accuarcy: 0.3488097154641089
# Total average train loss: 0.015258726615905762
#
# [ Test epoch: 1 ]
#
# Total average test accuarcy: 0.3912
# Total average test loss: 0.01791668162345886
# Model Saved!
#
# Time elapsed: 126.4758734703064
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.3902821549679593
# Current batch average train loss: 0.014834233559668064
#
# Current batch: 100
# Current batch average train accuracy: 0.29278435406418835
# Current batch average train loss: 0.01611459068953991
#
# Current batch: 200
# Current batch average train accuracy: 0.36840534949114256
# Current batch average train loss: 0.015621483325958252
#
# Current batch: 300
# Current batch average train accuracy: 0.31427664990221515
# Current batch average train loss: 0.01590396650135517
#
# Total average train accuarcy: 0.404441203702364
# Total average train loss: 0.014561697549819947
#
# [ Test epoch: 2 ]
#
# Total average test accuarcy: 0.4588
# Total average test loss: 0.017025049936771394
# Model Saved!
#
# Time elapsed: 190.1292600631714
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.35600330708177275
# Current batch average train loss: 0.01519140973687172
#
# Current batch: 100
# Current batch average train accuracy: 0.651738012117742
# Current batch average train loss: 0.011395292356610298
#
# Current batch: 200
# Current batch average train accuracy: 0.48614546678907455
# Current batch average train loss: 0.013450506143271923
#
# Current batch: 300
# Current batch average train accuracy: 0.4373574659819362
# Current batch average train loss: 0.014534931629896164
#
# Total average train accuarcy: 0.4544059776413456
# Total average train loss: 0.013882053232192992
#
# [ Test epoch: 3 ]
#
# Total average test accuarcy: 0.5289
# Total average test loss: 0.015759695172309875
# Model Saved!
#
# Time elapsed: 253.71214532852173
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.3743260139455444
# Current batch average train loss: 0.014908824115991592
#
# Current batch: 100
# Current batch average train accuracy: 0.43029424569754293
# Current batch average train loss: 0.014474442228674889
#
# Current batch: 200
# Current batch average train accuracy: 0.5277369076206723
# Current batch average train loss: 0.013226015493273735
#
# Current batch: 300
# Current batch average train accuracy: 0.45027510682559546
# Current batch average train loss: 0.014361130073666573
#
# Total average train accuarcy: 0.48014965412785704
# Total average train loss: 0.013585320439338685
#
# [ Test epoch: 4 ]
#
# Total average test accuarcy: 0.5717
# Total average test loss: 0.015029364848136903
# Model Saved!
#
# Time elapsed: 317.4326469898224
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6541191291141639
# Current batch average train loss: 0.011060086078941822
#
# Current batch: 100
# Current batch average train accuracy: 0.27458753183429485
# Current batch average train loss: 0.016431845724582672
#
# Current batch: 200
# Current batch average train accuracy: 0.4775607403155261
# Current batch average train loss: 0.013927871361374855
#
# Current batch: 300
# Current batch average train accuracy: 0.4183847210635727
# Current batch average train loss: 0.014572057873010635
#
# Total average train accuarcy: 0.4982421365848716
# Total average train loss: 0.013333018417358398
#
# [ Test epoch: 5 ]
#
# Total average test accuarcy: 0.6397
# Total average test loss: 0.013634457075595855
# Model Saved!
#
# Time elapsed: 381.2106065750122
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6100146160729806
# Current batch average train loss: 0.012028664350509644
#
# Current batch: 100
# Current batch average train accuracy: 0.7146981906995352
# Current batch average train loss: 0.009072496555745602
#
# Current batch: 200
# Current batch average train accuracy: 0.41218440899191927
# Current batch average train loss: 0.014734212309122086
#
# Current batch: 300
# Current batch average train accuracy: 0.4227369572161287
# Current batch average train loss: 0.014469994232058525
#
# Total average train accuarcy: 0.5379412829419664
# Total average train loss: 0.01276566632270813
#
# [ Test epoch: 6 ]
#
# Total average test accuarcy: 0.5705
# Total average test loss: 0.015035594379901885
# Model Saved!
#
# Time elapsed: 444.80924940109253
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.44348206644349364
# Current batch average train loss: 0.014346424490213394
#
# Current batch: 100
# Current batch average train accuracy: 0.656289236899926
# Current batch average train loss: 0.010956836864352226
#
# Current batch: 200
# Current batch average train accuracy: 0.5102044046632592
# Current batch average train loss: 0.013654012233018875
#
# Current batch: 300
# Current batch average train accuracy: 0.5409563826242845
# Current batch average train loss: 0.013552510179579258
#
# Total average train accuarcy: 0.5454506758730714
# Total average train loss: 0.012680412681102753
#
# [ Test epoch: 7 ]
#
# Total average test accuarcy: 0.6682
# Total average test loss: 0.01292356172800064
# Model Saved!
#
# Time elapsed: 508.39383125305176
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.453822667564615
# Current batch average train loss: 0.01406262256205082
#
# Current batch: 100
# Current batch average train accuracy: 0.6444730113563673
# Current batch average train loss: 0.01062305923551321
#
# Current batch: 200
# Current batch average train accuracy: 0.42499670576329573
# Current batch average train loss: 0.014227716252207756
#
# Current batch: 300
# Current batch average train accuracy: 0.4133086772139217
# Current batch average train loss: 0.014001043513417244
#
# Total average train accuarcy: 0.5668680733114774
# Total average train loss: 0.012341257393360137
#
# [ Test epoch: 8 ]
#
# Total average test accuarcy: 0.7035
# Total average test loss: 0.012585211062431335
# Model Saved!
#
# Time elapsed: 571.9801213741302
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6202876766149835
# Current batch average train loss: 0.0116799958050251
#
# Current batch: 100
# Current batch average train accuracy: 0.49345294117109506
# Current batch average train loss: 0.013450956903398037
#
# Current batch: 200
# Current batch average train accuracy: 0.6226716870479085
# Current batch average train loss: 0.01169953215867281
#
# Current batch: 300
# Current batch average train accuracy: 0.4054227933247678
# Current batch average train loss: 0.014529934152960777
#
# Total average train accuarcy: 0.5855362428695453
# Total average train loss: 0.012043875457048416
#
# [ Test epoch: 9 ]
#
# Total average test accuarcy: 0.7419
# Total average test loss: 0.01143278819322586
# Model Saved!
#
# Time elapsed: 635.600715637207
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7812294255908361
# Current batch average train loss: 0.007991970516741276
#
# Current batch: 100
# Current batch average train accuracy: 0.6716836947919662
# Current batch average train loss: 0.011380096897482872
#
# Current batch: 200
# Current batch average train accuracy: 0.4276883781476719
# Current batch average train loss: 0.013933373615145683
#
# Current batch: 300
# Current batch average train accuracy: 0.739998271030397
# Current batch average train loss: 0.008741522207856178
#
# Total average train accuarcy: 0.6065256208579198
# Total average train loss: 0.011753629404306411
#
# [ Test epoch: 10 ]
#
# Total average test accuarcy: 0.7532
# Total average test loss: 0.011584219324588776
# Model Saved!
#
# Time elapsed: 699.3861904144287
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6897751945332701
# Current batch average train loss: 0.010186695493757725
#
# Current batch: 100
# Current batch average train accuracy: 0.5487248613722999
# Current batch average train loss: 0.013043037615716457
#
# Current batch: 200
# Current batch average train accuracy: 0.5792075494967573
# Current batch average train loss: 0.012941435910761356
#
# Current batch: 300
# Current batch average train accuracy: 0.7239593076388219
# Current batch average train loss: 0.009526482783257961
#
# Total average train accuarcy: 0.6050979404819599
# Total average train loss: 0.011696265709400177
#
# [ Test epoch: 11 ]
#
# Total average test accuarcy: 0.7959
# Total average test loss: 0.01053959857225418
# Model Saved!
#
# Time elapsed: 762.982922077179
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6044318219005342
# Current batch average train loss: 0.01212506927549839
#
# Current batch: 100
# Current batch average train accuracy: 0.6763237907414947
# Current batch average train loss: 0.011208046227693558
#
# Current batch: 200
# Current batch average train accuracy: 0.4405408214719995
# Current batch average train loss: 0.013735400512814522
#
# Current batch: 300
# Current batch average train accuracy: 0.8433425029074073
# Current batch average train loss: 0.007277579512447119
#
# Total average train accuarcy: 0.6191107548083057
# Total average train loss: 0.011588930262327194
#
# [ Test epoch: 12 ]
#
# Total average test accuarcy: 0.7975
# Total average test loss: 0.010426692193746567
# Model Saved!
#
# Time elapsed: 826.6090087890625
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5135601080380985
# Current batch average train loss: 0.013436132110655308
#
# Current batch: 100
# Current batch average train accuracy: 0.5722688307687294
# Current batch average train loss: 0.012452984228730202
#
# Current batch: 200
# Current batch average train accuracy: 0.4377129573657287
# Current batch average train loss: 0.014244984835386276
#
# Current batch: 300
# Current batch average train accuracy: 0.5418043600837767
# Current batch average train loss: 0.012835737317800522
#
# Total average train accuarcy: 0.6181660612761213
# Total average train loss: 0.011586068314313889
#
# [ Test epoch: 13 ]
#
# Total average test accuarcy: 0.8136
# Total average test loss: 0.010256025969982147
# Model Saved!
#
# Time elapsed: 890.170102596283
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.556537800577567
# Current batch average train loss: 0.013214156031608582
#
# Current batch: 100
# Current batch average train accuracy: 0.7747646951120749
# Current batch average train loss: 0.008476853370666504
#
# Current batch: 200
# Current batch average train accuracy: 0.7944026009545104
# Current batch average train loss: 0.008182990364730358
#
# Current batch: 300
# Current batch average train accuracy: 0.4485436611050573
# Current batch average train loss: 0.013616448268294334
#
# Total average train accuarcy: 0.6250200433594874
# Total average train loss: 0.011451179267168045
#
# [ Test epoch: 14 ]
#
# Total average test accuarcy: 0.8196
# Total average test loss: 0.010186611074209213
# Model Saved!
#
# Time elapsed: 953.6591124534607
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4779435653465455
# Current batch average train loss: 0.013480901718139648
#
# Current batch: 100
# Current batch average train accuracy: 0.4024124869592999
# Current batch average train loss: 0.014257237315177917
#
# Current batch: 200
# Current batch average train accuracy: 0.4454725764401206
# Current batch average train loss: 0.013589052483439445
#
# Current batch: 300
# Current batch average train accuracy: 0.6178511478450565
# Current batch average train loss: 0.012091102078557014
#
# Total average train accuarcy: 0.6348835677626511
# Total average train loss: 0.011316432839632034
#
# [ Test epoch: 15 ]
#
# Total average test accuarcy: 0.8118
# Total average test loss: 0.01048214430809021
# Model Saved!
#
# Time elapsed: 1017.1852705478668
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8782670503155052
# Current batch average train loss: 0.007246112916618586
#
# Current batch: 100
# Current batch average train accuracy: 0.7570957050068167
# Current batch average train loss: 0.009035983122885227
#
# Current batch: 200
# Current batch average train accuracy: 0.5331402437794686
# Current batch average train loss: 0.013293350115418434
#
# Current batch: 300
# Current batch average train accuracy: 0.8191666251228351
# Current batch average train loss: 0.008490336127579212
#
# Total average train accuarcy: 0.6441521631329292
# Total average train loss: 0.01110726565361023
#
# [ Test epoch: 16 ]
#
# Total average test accuarcy: 0.8436
# Total average test loss: 0.009574643445014954
# Model Saved!
#
# Time elapsed: 1080.7829141616821
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6277725021142657
# Current batch average train loss: 0.01189335249364376
#
# Current batch: 100
# Current batch average train accuracy: 0.7352641015136211
# Current batch average train loss: 0.01036761049181223
#
# Current batch: 200
# Current batch average train accuracy: 0.5072434320523215
# Current batch average train loss: 0.012880425900220871
#
# Current batch: 300
# Current batch average train accuracy: 0.6397296441982145
# Current batch average train loss: 0.011010199785232544
#
# Total average train accuarcy: 0.6403807738943403
# Total average train loss: 0.011196920902729035
#
# [ Test epoch: 17 ]
#
# Total average test accuarcy: 0.8129
# Total average test loss: 0.010469671201705933
# Model Saved!
#
# Time elapsed: 1144.415091753006
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5198035609470434
# Current batch average train loss: 0.012776591815054417
#
# Current batch: 100
# Current batch average train accuracy: 0.8766944716390558
# Current batch average train loss: 0.00726250559091568
#
# Current batch: 200
# Current batch average train accuracy: 0.7821719444985346
# Current batch average train loss: 0.00861426629126072
#
# Current batch: 300
# Current batch average train accuracy: 0.8642162901825544
# Current batch average train loss: 0.00748040433973074
#
# Total average train accuarcy: 0.6464762579683138
# Total average train loss: 0.011121668900251389
#
# [ Test epoch: 18 ]
#
# Total average test accuarcy: 0.8499
# Total average test loss: 0.009363755482435227
# Model Saved!
#
# Time elapsed: 1207.9775216579437
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5596013471330372
# Current batch average train loss: 0.012483032420277596
#
# Current batch: 100
# Current batch average train accuracy: 0.828694219139446
# Current batch average train loss: 0.008100121282041073
#
# Current batch: 200
# Current batch average train accuracy: 0.4848107945658511
# Current batch average train loss: 0.013074498623609543
#
# Current batch: 300
# Current batch average train accuracy: 0.7451190020318212
# Current batch average train loss: 0.009871851652860641
#
# Total average train accuarcy: 0.6406677295540832
# Total average train loss: 0.011215453722476959
#
# [ Test epoch: 19 ]
#
# Total average test accuarcy: 0.8406
# Total average test loss: 0.009548234498500823
# Model Saved!
#
# Time elapsed: 1271.3892884254456
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8627815573795568
# Current batch average train loss: 0.007854660972952843
#
# Current batch: 100
# Current batch average train accuracy: 0.5613251337397072
# Current batch average train loss: 0.012928423471748829
#
# Current batch: 200
# Current batch average train accuracy: 0.8525453795824729
# Current batch average train loss: 0.0072491783648729324
#
# Current batch: 300
# Current batch average train accuracy: 0.8212731573236296
# Current batch average train loss: 0.008864977397024632
#
# Total average train accuarcy: 0.6547773615534433
# Total average train loss: 0.010936734095811845
#
# [ Test epoch: 20 ]
#
# Total average test accuarcy: 0.8582
# Total average test loss: 0.009306838870048522
# Model Saved!
#
# Time elapsed: 1334.8630237579346
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6121445569083329
# Current batch average train loss: 0.012045612558722496
#
# Current batch: 100
# Current batch average train accuracy: 0.763770906123861
# Current batch average train loss: 0.0096780676394701
#
# Current batch: 200
# Current batch average train accuracy: 0.5123982010834122
# Current batch average train loss: 0.012754743918776512
#
# Current batch: 300
# Current batch average train accuracy: 0.7054187352316742
# Current batch average train loss: 0.010629180818796158
#
# Total average train accuarcy: 0.6503913052851951
# Total average train loss: 0.011039972405433654
#
# [ Test epoch: 21 ]
#
# Total average test accuarcy: 0.8223
# Total average test loss: 0.010044127655029296
# Model Saved!
#
# Time elapsed: 1398.5628180503845
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5755751227901293
# Current batch average train loss: 0.012397805228829384
#
# Current batch: 100
# Current batch average train accuracy: 0.5029713176218027
# Current batch average train loss: 0.013397453352808952
#
# Current batch: 200
# Current batch average train accuracy: 0.8447248895966615
# Current batch average train loss: 0.00720848748460412
#
# Current batch: 300
# Current batch average train accuracy: 0.8776916980797279
# Current batch average train loss: 0.006369462236762047
#
# Total average train accuarcy: 0.6624242965768506
# Total average train loss: 0.010858776487112046
#
# [ Test epoch: 22 ]
#
# Total average test accuarcy: 0.8611
# Total average test loss: 0.009583769255876541
# Model Saved!
#
# Time elapsed: 1461.9918134212494
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8723637160534288
# Current batch average train loss: 0.007757529150694609
#
# Current batch: 100
# Current batch average train accuracy: 0.8134932716255483
# Current batch average train loss: 0.008795516565442085
#
# Current batch: 200
# Current batch average train accuracy: 0.7571918903248916
# Current batch average train loss: 0.009647104889154434
#
# Current batch: 300
# Current batch average train accuracy: 0.6592140540253486
# Current batch average train loss: 0.011550774797797203
#
# Total average train accuarcy: 0.6537167067466962
# Total average train loss: 0.0109234789955616
#
# [ Test epoch: 23 ]
#
# Total average test accuarcy: 0.8269
# Total average test loss: 0.010010857540369034
# Model Saved!
#
# Time elapsed: 1525.4338684082031
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.49903565677888123
# Current batch average train loss: 0.013134041801095009
#
# Current batch: 100
# Current batch average train accuracy: 0.46776161156248053
# Current batch average train loss: 0.013363766483962536
#
# Current batch: 200
# Current batch average train accuracy: 0.4823875049594235
# Current batch average train loss: 0.01328265480697155
#
# Current batch: 300
# Current batch average train accuracy: 0.5658000146483799
# Current batch average train loss: 0.012313855811953545
#
# Total average train accuarcy: 0.6506386103805423
# Total average train loss: 0.01097064984679222
#
# [ Test epoch: 24 ]
#
# Total average test accuarcy: 0.8661
# Total average test loss: 0.00926821370124817
# Model Saved!
#
# Time elapsed: 1588.9026663303375
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7289413615544355
# Current batch average train loss: 0.01020795851945877
#
# Current batch: 100
# Current batch average train accuracy: 0.6144723357054954
# Current batch average train loss: 0.011907648295164108
#
# Current batch: 200
# Current batch average train accuracy: 0.5670420683359778
# Current batch average train loss: 0.012324368581175804
#
# Current batch: 300
# Current batch average train accuracy: 0.46064881604095265
# Current batch average train loss: 0.013722294010221958
#
# Total average train accuarcy: 0.6670892555523728
# Total average train loss: 0.010778709917068481
#
# [ Test epoch: 25 ]
#
# Total average test accuarcy: 0.8622
# Total average test loss: 0.009107314819097519
# Model Saved!
#
# Time elapsed: 1652.3595323562622
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8671263518556483
# Current batch average train loss: 0.007378025911748409
#
# Current batch: 100
# Current batch average train accuracy: 0.8274996803419861
# Current batch average train loss: 0.00851577427238226
#
# Current batch: 200
# Current batch average train accuracy: 0.9085024604990809
# Current batch average train loss: 0.006431366316974163
#
# Current batch: 300
# Current batch average train accuracy: 0.6570672681666538
# Current batch average train loss: 0.011521000415086746
#
# Total average train accuarcy: 0.6621202842724436
# Total average train loss: 0.010811902966499328
#
# [ Test epoch: 26 ]
#
# Total average test accuarcy: 0.8465
# Total average test loss: 0.009582910811901093
# Model Saved!
#
# Time elapsed: 1715.8337864875793
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6530651798997887
# Current batch average train loss: 0.011599411256611347
#
# Current batch: 100
# Current batch average train accuracy: 0.6553100537691989
# Current batch average train loss: 0.011586692184209824
#
# Current batch: 200
# Current batch average train accuracy: 0.5087423863726062
# Current batch average train loss: 0.013151556253433228
#
# Current batch: 300
# Current batch average train accuracy: 0.41779601587403287
# Current batch average train loss: 0.013746846467256546
#
# Total average train accuarcy: 0.6677217448713139
# Total average train loss: 0.010693870965242385
#
# [ Test epoch: 27 ]
#
# Total average test accuarcy: 0.8528
# Total average test loss: 0.009084748989343644
# Model Saved!
#
# Time elapsed: 1779.3294167518616
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9463007482723035
# Current batch average train loss: 0.005840884521603584
#
# Current batch: 100
# Current batch average train accuracy: 0.9198675764381234
# Current batch average train loss: 0.006761116907000542
#
# Current batch: 200
# Current batch average train accuracy: 0.4926119657152102
# Current batch average train loss: 0.012975290417671204
#
# Current batch: 300
# Current batch average train accuracy: 0.8720739331913043
# Current batch average train loss: 0.00715754646807909
#
# Total average train accuarcy: 0.6669666892075047
# Total average train loss: 0.010762195560932159
#
# [ Test epoch: 28 ]
#
# Total average test accuarcy: 0.8744
# Total average test loss: 0.008947293043136597
# Model Saved!
#
# Time elapsed: 1842.8257088661194
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5508514570715203
# Current batch average train loss: 0.01262813713401556
#
# Current batch: 100
# Current batch average train accuracy: 0.6783779113485475
# Current batch average train loss: 0.010908285155892372
#
# Current batch: 200
# Current batch average train accuracy: 0.8328202939311854
# Current batch average train loss: 0.008391874842345715
#
# Current batch: 300
# Current batch average train accuracy: 0.5132708969804219
# Current batch average train loss: 0.01344233751296997
#
# Total average train accuarcy: 0.6729947726595524
# Total average train loss: 0.010649706579446793
#
# [ Test epoch: 29 ]
#
# Total average test accuarcy: 0.8394
# Total average test loss: 0.00977602362036705
# Model Saved!
#
# Time elapsed: 1906.5178503990173
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8391738059266012
# Current batch average train loss: 0.007463851477950811
#
# Current batch: 100
# Current batch average train accuracy: 0.8377228408105161
# Current batch average train loss: 0.008218269795179367
#
# Current batch: 200
# Current batch average train accuracy: 0.7120851859407312
# Current batch average train loss: 0.010402049869298935
#
# Current batch: 300
# Current batch average train accuracy: 0.6182258539930421
# Current batch average train loss: 0.011830372735857964
#
# Total average train accuarcy: 0.6625326630077357
# Total average train loss: 0.010785096722841264
#
# [ Test epoch: 30 ]
#
# Total average test accuarcy: 0.8603
# Total average test loss: 0.009613522344827652
# Model Saved!
#
# Time elapsed: 1969.9925010204315
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5551547828291962
# Current batch average train loss: 0.012431580573320389
#
# Current batch: 100
# Current batch average train accuracy: 0.4912188936192853
# Current batch average train loss: 0.013247056864202023
#
# Current batch: 200
# Current batch average train accuracy: 0.8112010059594823
# Current batch average train loss: 0.008396690711379051
#
# Current batch: 300
# Current batch average train accuracy: 0.6979971019886019
# Current batch average train loss: 0.01115370448678732
#
# Total average train accuarcy: 0.6720193985793192
# Total average train loss: 0.010669752303361892
#
# [ Test epoch: 31 ]
#
# Total average test accuarcy: 0.8537
# Total average test loss: 0.009527343893051148
# Model Saved!
#
# Time elapsed: 2033.420113325119
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.914130439833094
# Current batch average train loss: 0.006127648055553436
#
# Current batch: 100
# Current batch average train accuracy: 0.4571674450729056
# Current batch average train loss: 0.01323182974010706
#
# Current batch: 200
# Current batch average train accuracy: 0.6085492635777432
# Current batch average train loss: 0.0115431509912014
#
# Current batch: 300
# Current batch average train accuracy: 0.8407334924624933
# Current batch average train loss: 0.007957898080348969
#
# Total average train accuarcy: 0.6784335748445356
# Total average train loss: 0.01049647732257843
#
# [ Test epoch: 32 ]
#
# Total average test accuarcy: 0.885
# Total average test loss: 0.008967433190345764
# Model Saved!
#
# Time elapsed: 2097.012148141861
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5967502940747392
# Current batch average train loss: 0.012081148102879524
#
# Current batch: 100
# Current batch average train accuracy: 0.6135866713435505
# Current batch average train loss: 0.011886406689882278
#
# Current batch: 200
# Current batch average train accuracy: 0.814514299327906
# Current batch average train loss: 0.008157684467732906
#
# Current batch: 300
# Current batch average train accuracy: 0.537201406822661
# Current batch average train loss: 0.012478728778660297
#
# Total average train accuarcy: 0.6845160499443301
# Total average train loss: 0.010399024251699448
#
# [ Test epoch: 33 ]
#
# Total average test accuarcy: 0.8696
# Total average test loss: 0.009587159723043442
# Model Saved!
#
# Time elapsed: 2160.3393671512604
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.46935211950151756
# Current batch average train loss: 0.01364310272037983
#
# Current batch: 100
# Current batch average train accuracy: 0.9096563136557094
# Current batch average train loss: 0.006283616181463003
#
# Current batch: 200
# Current batch average train accuracy: 0.8813160258289515
# Current batch average train loss: 0.007094408385455608
#
# Current batch: 300
# Current batch average train accuracy: 0.7910102589324113
# Current batch average train loss: 0.008996972814202309
#
# Total average train accuarcy: 0.6823855323166006
# Total average train loss: 0.010455702483654022
#
# [ Test epoch: 34 ]
#
# Total average test accuarcy: 0.839
# Total average test loss: 0.009678549414873124
# Model Saved!
#
# Time elapsed: 2223.735233068466
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6505753935957292
# Current batch average train loss: 0.010977964848279953
#
# Current batch: 100
# Current batch average train accuracy: 0.7476724815627662
# Current batch average train loss: 0.010067167691886425
#
# Current batch: 200
# Current batch average train accuracy: 0.49940332889742345
# Current batch average train loss: 0.012553488835692406
#
# Current batch: 300
# Current batch average train accuracy: 0.6705318266793369
# Current batch average train loss: 0.011341139674186707
#
# Total average train accuarcy: 0.6802860493704036
# Total average train loss: 0.01048223379611969
#
# [ Test epoch: 35 ]
#
# Total average test accuarcy: 0.8676
# Total average test loss: 0.009027608674764633
# Model Saved!
#
# Time elapsed: 2287.196761369705
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.699410230544912
# Current batch average train loss: 0.010666253045201302
#
# Current batch: 100
# Current batch average train accuracy: 0.492494298076441
# Current batch average train loss: 0.012976609170436859
#
# Current batch: 200
# Current batch average train accuracy: 0.5361665701708579
# Current batch average train loss: 0.012588957324624062
#
# Current batch: 300
# Current batch average train accuracy: 0.6083324140358491
# Current batch average train loss: 0.011898660100996494
#
# Total average train accuarcy: 0.6813195527964546
# Total average train loss: 0.010442122322320939
#
# [ Test epoch: 36 ]
#
# Total average test accuarcy: 0.857
# Total average test loss: 0.00946011083126068
# Model Saved!
#
# Time elapsed: 2350.5270626544952
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5574403072553874
# Current batch average train loss: 0.012607011944055557
#
# Current batch: 100
# Current batch average train accuracy: 0.7883638779386479
# Current batch average train loss: 0.009053836576640606
#
# Current batch: 200
# Current batch average train accuracy: 0.7671677317786885
# Current batch average train loss: 0.009737899526953697
#
# Current batch: 300
# Current batch average train accuracy: 0.6841841742500991
# Current batch average train loss: 0.010822953656315804
#
# Total average train accuarcy: 0.684918879944417
# Total average train loss: 0.010395457000732421
#
# [ Test epoch: 37 ]
#
# Total average test accuarcy: 0.881
# Total average test loss: 0.008711934053897858
# Model Saved!
#
# Time elapsed: 2413.984377145767
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5781737591839614
# Current batch average train loss: 0.012302436865866184
#
# Current batch: 100
# Current batch average train accuracy: 0.7979562364705913
# Current batch average train loss: 0.008761623874306679
#
# Current batch: 200
# Current batch average train accuracy: 0.9150935451785189
# Current batch average train loss: 0.006045590620487928
#
# Current batch: 300
# Current batch average train accuracy: 0.5551197938938696
# Current batch average train loss: 0.01264871098101139
#
# Total average train accuarcy: 0.6803471120049243
# Total average train loss: 0.01046448179244995
#
# [ Test epoch: 38 ]
#
# Total average test accuarcy: 0.8605
# Total average test loss: 0.009348666489124299
# Model Saved!
#
# Time elapsed: 2477.3685069084167
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5504394748291482
# Current batch average train loss: 0.012445553205907345
#
# Current batch: 100
# Current batch average train accuracy: 0.47000716623116084
# Current batch average train loss: 0.013336725533008575
#
# Current batch: 200
# Current batch average train accuracy: 0.4675845771415357
# Current batch average train loss: 0.013420555740594864
#
# Current batch: 300
# Current batch average train accuracy: 0.46598224675324756
# Current batch average train loss: 0.012808563187718391
#
# Total average train accuarcy: 0.6807561472352455
# Total average train loss: 0.010429428963661194
#
# [ Test epoch: 39 ]
#
# Total average test accuarcy: 0.8232
# Total average test loss: 0.009963790863752365
# Model Saved!
#
# Time elapsed: 2540.7689859867096
#
# [ Train epoch: 40 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6342347534518878
# Current batch average train loss: 0.011236034333705902
#
# Current batch: 100
# Current batch average train accuracy: 0.8174510712667942
# Current batch average train loss: 0.0088752880692482
#
# Current batch: 200
# Current batch average train accuracy: 0.7583916822303544
# Current batch average train loss: 0.01010533981025219
#
# Current batch: 300
# Current batch average train accuracy: 0.5171110175316035
# Current batch average train loss: 0.012721124105155468
#
# Total average train accuarcy: 0.682220171660495
# Total average train loss: 0.01043490159034729
#
# [ Test epoch: 40 ]
#
# Total average test accuarcy: 0.8732
# Total average test loss: 0.008929967546463012
# Model Saved!
#
# Time elapsed: 2604.2860946655273
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7039142329304989
# Current batch average train loss: 0.010472936555743217
#
# Current batch: 100
# Current batch average train accuracy: 0.45695113966021417
# Current batch average train loss: 0.012988144531846046
#
# Current batch: 200
# Current batch average train accuracy: 0.5753907095434778
# Current batch average train loss: 0.012203121557831764
#
# Current batch: 300
# Current batch average train accuracy: 0.7614403737442068
# Current batch average train loss: 0.009449698030948639
#
# Total average train accuarcy: 0.6873451733335982
# Total average train loss: 0.010377223663330078
#
# [ Test epoch: 41 ]
#
# Total average test accuarcy: 0.8706
# Total average test loss: 0.00921683229804039
# Model Saved!
#
# Time elapsed: 2667.932948589325
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.911735624058182
# Current batch average train loss: 0.006394929252564907
#
# Current batch: 100
# Current batch average train accuracy: 0.6894683086211718
# Current batch average train loss: 0.01099166739732027
#
# Current batch: 200
# Current batch average train accuracy: 0.5980183917108681
# Current batch average train loss: 0.011733395978808403
#
# Current batch: 300
# Current batch average train accuracy: 0.4712086222878178
# Current batch average train loss: 0.013349337503314018
#
# Total average train accuarcy: 0.6845760350323021
# Total average train loss: 0.010381172355413438
#
# [ Test epoch: 42 ]
#
# Total average test accuarcy: 0.8357
# Total average test loss: 0.009701357787847519
# Model Saved!
#
# Time elapsed: 2731.4276218414307
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4808640525340009
# Current batch average train loss: 0.013068808242678642
#
# Current batch: 100
# Current batch average train accuracy: 0.5602083834042778
# Current batch average train loss: 0.012228044681251049
#
# Current batch: 200
# Current batch average train accuracy: 0.5867789120474098
# Current batch average train loss: 0.012224303558468819
#
# Current batch: 300
# Current batch average train accuracy: 0.8101298972540069
# Current batch average train loss: 0.008613591082394123
#
# Total average train accuarcy: 0.6790734731245648
# Total average train loss: 0.010449316591024398
#
# [ Test epoch: 43 ]
#
# Total average test accuarcy: 0.8775
# Total average test loss: 0.008919714850187301
# Model Saved!
#
# Time elapsed: 2794.862874507904
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.48693104017147115
# Current batch average train loss: 0.01251104474067688
#
# Current batch: 100
# Current batch average train accuracy: 0.6254910277953996
# Current batch average train loss: 0.011679908260703087
#
# Current batch: 200
# Current batch average train accuracy: 0.5838006556731494
# Current batch average train loss: 0.012041418813169003
#
# Current batch: 300
# Current batch average train accuracy: 0.5945159611200248
# Current batch average train loss: 0.01212683692574501
#
# Total average train accuarcy: 0.6869537947668655
# Total average train loss: 0.010340512268543243
#
# [ Test epoch: 44 ]
#
# Total average test accuarcy: 0.8884
# Total average test loss: 0.008347078323364258
# Model Saved!
#
# Time elapsed: 2858.321851015091
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.48183756283771734
# Current batch average train loss: 0.01328508835285902
#
# Current batch: 100
# Current batch average train accuracy: 0.8822454448782153
# Current batch average train loss: 0.006892343983054161
#
# Current batch: 200
# Current batch average train accuracy: 0.8966569568611061
# Current batch average train loss: 0.006554747465997934
#
# Current batch: 300
# Current batch average train accuracy: 0.7156513534281366
# Current batch average train loss: 0.010327760130167007
#
# Total average train accuarcy: 0.6694359065377996
# Total average train loss: 0.010577928664684296
#
# [ Test epoch: 45 ]
#
# Total average test accuarcy: 0.8646
# Total average test loss: 0.009150940150022506
# Model Saved!
#
# Time elapsed: 2921.7493419647217
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.44715744767887616
# Current batch average train loss: 0.013246077112853527
#
# Current batch: 100
# Current batch average train accuracy: 0.5346131392512703
# Current batch average train loss: 0.012589434161782265
#
# Current batch: 200
# Current batch average train accuracy: 0.6347766127475999
# Current batch average train loss: 0.011608812026679516
#
# Current batch: 300
# Current batch average train accuracy: 0.6059177394437721
# Current batch average train loss: 0.011739090085029602
#
# Total average train accuarcy: 0.6776543024185196
# Total average train loss: 0.010482231489419937
#
# [ Test epoch: 46 ]
#
# Total average test accuarcy: 0.8736
# Total average test loss: 0.009286771720647811
# Model Saved!
#
# Time elapsed: 2985.302321910858
#
# [ Train epoch: 47 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8501209547064115
# Current batch average train loss: 0.007691279985010624
#
# Current batch: 100
# Current batch average train accuracy: 0.620645656880492
# Current batch average train loss: 0.011753903701901436
#
# Current batch: 200
# Current batch average train accuracy: 0.5447422958986974
# Current batch average train loss: 0.01243968028575182
#
# Current batch: 300
# Current batch average train accuracy: 0.7488542027046489
# Current batch average train loss: 0.009463869035243988
#
# Total average train accuarcy: 0.6835666219617352
# Total average train loss: 0.010373292150497437
#
# [ Test epoch: 47 ]
#
# Total average test accuarcy: 0.8904
# Total average test loss: 0.008484031665325164
# Model Saved!
#
# Time elapsed: 3048.9968605041504
#
# [ Train epoch: 48 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8919515523009558
# Current batch average train loss: 0.006396108772605658
#
# Current batch: 100
# Current batch average train accuracy: 0.8836749030677433
# Current batch average train loss: 0.006958381272852421
#
# Current batch: 200
# Current batch average train accuracy: 0.6471798452401456
# Current batch average train loss: 0.011699692346155643
#
# Current batch: 300
# Current batch average train accuracy: 0.4823969894789936
# Current batch average train loss: 0.01360032893717289
#
# Total average train accuarcy: 0.6863908950500931
# Total average train loss: 0.010369536217451096
#
# [ Test epoch: 48 ]
#
# Total average test accuarcy: 0.8951
# Total average test loss: 0.008924492883682252
# Model Saved!
#
# Time elapsed: 3112.3965821266174
#
# [ Train epoch: 49 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5136112085815355
# Current batch average train loss: 0.012224840000271797
#
# Current batch: 100
# Current batch average train accuracy: 0.6861495042623856
# Current batch average train loss: 0.010917380452156067
#
# Current batch: 200
# Current batch average train accuracy: 0.7372985526552671
# Current batch average train loss: 0.009932931512594223
#
# Current batch: 300
# Current batch average train accuracy: 0.7676249291886721
# Current batch average train loss: 0.009693456813693047
#
# Total average train accuarcy: 0.6841278603380345
# Total average train loss: 0.010349069870710373
#
# [ Test epoch: 49 ]
#
# Total average test accuarcy: 0.8761
# Total average test loss: 0.008803458225727081
# Model Saved!
#
# Time elapsed: 3175.6999266147614
#
# [ Train epoch: 50 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.49544865209072286
# Current batch average train loss: 0.012999359518289566
#
# Current batch: 100
# Current batch average train accuracy: 0.8410733643181584
# Current batch average train loss: 0.008289560675621033
#
# Current batch: 200
# Current batch average train accuracy: 0.9195785711470469
# Current batch average train loss: 0.0059609669260680676
#
# Current batch: 300
# Current batch average train accuracy: 0.748181579801577
# Current batch average train loss: 0.009920274838805199
#
# Total average train accuarcy: 0.7069298488034311
# Total average train loss: 0.009922407742738724
#
# [ Test epoch: 50 ]
#
# Total average test accuarcy: 0.9317
# Total average test loss: 0.007926711589097976
# Model Saved!
#
# Time elapsed: 3239.0926587581635
#
# [ Train epoch: 51 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9174900972134601
# Current batch average train loss: 0.00598858343437314
#
# Current batch: 100
# Current batch average train accuracy: 0.9066854236745899
# Current batch average train loss: 0.006767998915165663
#
# Current batch: 200
# Current batch average train accuracy: 0.7126152848831914
# Current batch average train loss: 0.01037956215441227
#
# Current batch: 300
# Current batch average train accuracy: 0.6545064955414472
# Current batch average train loss: 0.011153386905789375
#
# Total average train accuarcy: 0.7135869124532501
# Total average train loss: 0.009770841919183731
#
# [ Test epoch: 51 ]
#
# Total average test accuarcy: 0.9376
# Total average test loss: 0.007597009527683258
# Model Saved!
#
# Time elapsed: 3302.4596803188324
#
# [ Train epoch: 52 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9355528373896779
# Current batch average train loss: 0.006115065887570381
#
# Current batch: 100
# Current batch average train accuracy: 0.5447596306277457
# Current batch average train loss: 0.01213783584535122
#
# Current batch: 200
# Current batch average train accuracy: 0.7195834084025106
# Current batch average train loss: 0.009704360738396645
#
# Current batch: 300
# Current batch average train accuracy: 0.6162062826639381
# Current batch average train loss: 0.010890619829297066
#
# Total average train accuarcy: 0.7138917413138999
# Total average train loss: 0.009722580769062043
#
# [ Test epoch: 52 ]
#
# Total average test accuarcy: 0.9381
# Total average test loss: 0.007759892952442169
# Model Saved!
#
# Time elapsed: 3365.87935590744
#
# [ Train epoch: 53 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5480460468920909
# Current batch average train loss: 0.01181456446647644
#
# Current batch: 100
# Current batch average train accuracy: 0.5369525599508399
# Current batch average train loss: 0.011524271219968796
#
# Current batch: 200
# Current batch average train accuracy: 0.8933982455109074
# Current batch average train loss: 0.0064014894887804985
#
# Current batch: 300
# Current batch average train accuracy: 0.5144575702443253
# Current batch average train loss: 0.011647081933915615
#
# Total average train accuarcy: 0.7335903563490975
# Total average train loss: 0.009442626502513886
#
# [ Test epoch: 53 ]
#
# Total average test accuarcy: 0.9362
# Total average test loss: 0.007726132375001907
# Model Saved!
#
# Time elapsed: 3429.3079376220703
#
# [ Train epoch: 54 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7862637172736253
# Current batch average train loss: 0.009162073954939842
#
# Current batch: 100
# Current batch average train accuracy: 0.7520912014898112
# Current batch average train loss: 0.00969199649989605
#
# Current batch: 200
# Current batch average train accuracy: 0.5294644598351834
# Current batch average train loss: 0.011621380224823952
#
# Current batch: 300
# Current batch average train accuracy: 0.9387604722652497
# Current batch average train loss: 0.006141343619674444
#
# Total average train accuarcy: 0.7106590390642809
# Total average train loss: 0.009714244693517685
#
# [ Test epoch: 54 ]
#
# Total average test accuarcy: 0.9399
# Total average test loss: 0.007564645034074783
# Model Saved!
#
# Time elapsed: 3492.6343715190887
#
# [ Train epoch: 55 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.960471951195013
# Current batch average train loss: 0.0051579950377345085
#
# Current batch: 100
# Current batch average train accuracy: 0.5190018159131159
# Current batch average train loss: 0.011452963575720787
#
# Current batch: 200
# Current batch average train accuracy: 0.5360679298960952
# Current batch average train loss: 0.011828804388642311
#
# Current batch: 300
# Current batch average train accuracy: 0.9528632682148968
# Current batch average train loss: 0.005742789711803198
#
# Total average train accuarcy: 0.7154943117135038
# Total average train loss: 0.0096057479262352
#
# [ Test epoch: 55 ]
#
# Total average test accuarcy: 0.938
# Total average test loss: 0.00773179082274437
# Model Saved!
#
# Time elapsed: 3556.0731661319733
#
# [ Train epoch: 56 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8002506199986956
# Current batch average train loss: 0.009211634285748005
#
# Current batch: 100
# Current batch average train accuracy: 0.83422789840953
# Current batch average train loss: 0.008201031014323235
#
# Current batch: 200
# Current batch average train accuracy: 0.8950317482388312
# Current batch average train loss: 0.007193863391876221
#
# Current batch: 300
# Current batch average train accuracy: 0.9495809797894337
# Current batch average train loss: 0.005282856989651918
#
# Total average train accuarcy: 0.7225519187792345
# Total average train loss: 0.009529658402204514
#
# [ Test epoch: 56 ]
#
# Total average test accuarcy: 0.9414
# Total average test loss: 0.007497943091392517
# Model Saved!
#
# Time elapsed: 3619.509681224823
#
# [ Train epoch: 57 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9460096175404403
# Current batch average train loss: 0.005700823850929737
#
# Current batch: 100
# Current batch average train accuracy: 0.6169500514041136
# Current batch average train loss: 0.011309796944260597
#
# Current batch: 200
# Current batch average train accuracy: 0.9402571488705908
# Current batch average train loss: 0.0059930612333118916
#
# Current batch: 300
# Current batch average train accuracy: 0.707775124179995
# Current batch average train loss: 0.010188505984842777
#
# Total average train accuarcy: 0.740458321958495
# Total average train loss: 0.009364573920965194
#
# [ Test epoch: 57 ]
#
# Total average test accuarcy: 0.9406
# Total average test loss: 0.007887085688114167
# Model Saved!
#
# Time elapsed: 3682.9086396694183
#
# [ Train epoch: 58 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5459902484990335
# Current batch average train loss: 0.011538914404809475
#
# Current batch: 100
# Current batch average train accuracy: 0.9076446777963024
# Current batch average train loss: 0.0063702696934342384
#
# Current batch: 200
# Current batch average train accuracy: 0.7752969626641991
# Current batch average train loss: 0.009661353193223476
#
# Current batch: 300
# Current batch average train accuracy: 0.6960766728869987
# Current batch average train loss: 0.010066168382763863
#
# Total average train accuarcy: 0.729694591712522
# Total average train loss: 0.009387544559240341
#
# [ Test epoch: 58 ]
#
# Total average test accuarcy: 0.942
# Total average test loss: 0.007588605833053589
# Model Saved!
#
# Time elapsed: 3746.265198945999
#
# [ Train epoch: 59 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8460160960404078
# Current batch average train loss: 0.0081993592903018
#
# Current batch: 100
# Current batch average train accuracy: 0.5704248274316306
# Current batch average train loss: 0.011239012703299522
#
# Current batch: 200
# Current batch average train accuracy: 0.6914787391044123
# Current batch average train loss: 0.010549444705247879
#
# Current batch: 300
# Current batch average train accuracy: 0.6840919571247888
# Current batch average train loss: 0.010522587224841118
#
# Total average train accuarcy: 0.7165000037413731
# Total average train loss: 0.009549566494226456
#
# [ Test epoch: 59 ]
#
# Total average test accuarcy: 0.9422
# Total average test loss: 0.007476227796077728
# Model Saved!
#
# Time elapsed: 3809.6873908042908
#
# [ Train epoch: 60 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6160942371563123
# Current batch average train loss: 0.010746270418167114
#
# Current batch: 100
# Current batch average train accuracy: 0.8809739326463741
# Current batch average train loss: 0.007410065270960331
#
# Current batch: 200
# Current batch average train accuracy: 0.5857596944364081
# Current batch average train loss: 0.011406825855374336
#
# Current batch: 300
# ...
#
# Total average test accuarcy: 0.9548
# Total average test loss: 0.007106565123796463
# Model Saved!
#
# Time elapsed: 8250.889254331589
#
# [ Train epoch: 130 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6896139561661015
# Current batch average train loss: 0.00996358972042799
#
# Current batch: 100
# Current batch average train accuracy: 0.5383916879893891
# Current batch average train loss: 0.010673350654542446
#
# Current batch: 200
# Current batch average train accuracy: 0.8779765322347917
# Current batch average train loss: 0.007458670996129513
#
# Current batch: 300
# Current batch average train accuracy: 0.966512019112845
# Current batch average train loss: 0.005315084010362625
#
# Total average train accuarcy: 0.7562680444494672
# Total average train loss: 0.008694426349401475
#
# [ Test epoch: 130 ]
#
# Total average test accuarcy: 0.9537
# Total average test loss: 0.007326120299100876
# Model Saved!
#
# Time elapsed: 8314.305341243744
#
# [ Train epoch: 131 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.693455856612236
# Current batch average train loss: 0.009896580129861832
#
# Current batch: 100
# Current batch average train accuracy: 0.5312197459475692
# Current batch average train loss: 0.011359062045812607
#
# Current batch: 200
# Current batch average train accuracy: 0.7447355902712017
# Current batch average train loss: 0.009464306756854057
#
# Current batch: 300
# Current batch average train accuracy: 0.9272302189410893
# Current batch average train loss: 0.006363283842802048
#
# Total average train accuarcy: 0.7500010685593472
# Total average train loss: 0.008820144793987274
#
# [ Test epoch: 131 ]
#
# Total average test accuarcy: 0.9553
# Total average test loss: 0.007286097580194473
# Model Saved!
#
# Time elapsed: 8377.745991706848
#
# [ Train epoch: 132 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8921200802840996
# Current batch average train loss: 0.007112294435501099
#
# Current batch: 100
# Current batch average train accuracy: 0.8932751620488918
# Current batch average train loss: 0.0071433912962675095
#
# Current batch: 200
# Current batch average train accuracy: 0.6514312027989884
# Current batch average train loss: 0.010109391063451767
#
# Current batch: 300
# Current batch average train accuracy: 0.7583362238206266
# Current batch average train loss: 0.009217571467161179
#
# Total average train accuarcy: 0.7553233397689226
# Total average train loss: 0.00868522405385971
#
# [ Test epoch: 132 ]
#
# Total average test accuarcy: 0.9562
# Total average test loss: 0.007013164937496185
# Model Saved!
#
# Time elapsed: 8441.20385837555
#
# [ Train epoch: 133 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7838032730056007
# Current batch average train loss: 0.009259361773729324
#
# Current batch: 100
# Current batch average train accuracy: 0.717030099112132
# Current batch average train loss: 0.010118871927261353
#
# Current batch: 200
# Current batch average train accuracy: 0.5709328560488165
# Current batch average train loss: 0.010710962116718292
#
# Current batch: 300
# Current batch average train accuracy: 0.5754954820498575
# Current batch average train loss: 0.010582949966192245
#
# Total average train accuarcy: 0.7476883681384822
# Total average train loss: 0.008787438271045684
#
# [ Test epoch: 133 ]
#
# Total average test accuarcy: 0.9558
# Total average test loss: 0.00711973956823349
# Model Saved!
#
# Time elapsed: 8504.613948106766
#
# [ Train epoch: 134 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5339735108423574
# Current batch average train loss: 0.010655198246240616
#
# Current batch: 100
# Current batch average train accuracy: 0.6630604417183243
# Current batch average train loss: 0.010277499444782734
#
# Current batch: 200
# Current batch average train accuracy: 0.5004258764916224
# Current batch average train loss: 0.01100592128932476
#
# Current batch: 300
# Current batch average train accuracy: 0.8466254400752395
# Current batch average train loss: 0.008060745894908905
#
# Total average train accuarcy: 0.7569353219256681
# Total average train loss: 0.008714357589483262
#
# [ Test epoch: 134 ]
#
# Total average test accuarcy: 0.9561
# Total average test loss: 0.0069686927735805515
# Model Saved!
#
# Time elapsed: 8568.190101861954
#
# [ Train epoch: 135 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6664411155497132
# Current batch average train loss: 0.010297533124685287
#
# Current batch: 100
# Current batch average train accuracy: 0.57011724382114
# Current batch average train loss: 0.010739326477050781
#
# Current batch: 200
# Current batch average train accuracy: 0.9377993922045076
# Current batch average train loss: 0.006050067953765392
#
# Current batch: 300
# Current batch average train accuracy: 0.7013684282944206
# Current batch average train loss: 0.009990088641643524
#
# Total average train accuarcy: 0.7416314533057217
# Total average train loss: 0.008864097561836242
#
# [ Test epoch: 135 ]
#
# Total average test accuarcy: 0.9537
# Total average test loss: 0.007133957475423813
# Model Saved!
#
# Time elapsed: 8631.649966478348
#
# [ Train epoch: 136 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8518027062465588
# Current batch average train loss: 0.007961217314004898
#
# Current batch: 100
# Current batch average train accuracy: 0.939712495289176
# Current batch average train loss: 0.006030939519405365
#
# Current batch: 200
# Current batch average train accuracy: 0.7636007162617882
# Current batch average train loss: 0.008890071883797646
#
# Current batch: 300
# Current batch average train accuracy: 0.6977586299705267
# Current batch average train loss: 0.009811947122216225
#
# Total average train accuarcy: 0.7533019076603101
# Total average train loss: 0.00873629362821579
#
# [ Test epoch: 136 ]
#
# Total average test accuarcy: 0.9562
# Total average test loss: 0.007081291788816452
# Model Saved!
#
# Time elapsed: 8695.24150300026
#
# [ Train epoch: 137 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5882759581582103
# Current batch average train loss: 0.0104442797601223
#
# Current batch: 100
# Current batch average train accuracy: 0.8016265797757366
# Current batch average train loss: 0.008815404027700424
#
# Current batch: 200
# Current batch average train accuracy: 0.7862311619893931
# Current batch average train loss: 0.009221093729138374
#
# Current batch: 300
# Current batch average train accuracy: 0.9325601192301995
# Current batch average train loss: 0.006030338816344738
#
# Total average train accuarcy: 0.7618462130451995
# Total average train loss: 0.008627715363502502
#
# [ Test epoch: 137 ]
#
# Total average test accuarcy: 0.956
# Total average test loss: 0.007078345358371735
# Model Saved!
#
# Time elapsed: 8758.910737276077
#
# [ Train epoch: 138 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5555817450224381
# Current batch average train loss: 0.010218964889645576
#
# Current batch: 100
# Current batch average train accuracy: 0.5600038152677779
# Current batch average train loss: 0.01127624325454235
#
# Current batch: 200
# Current batch average train accuracy: 0.9183762040103068
# Current batch average train loss: 0.006541116163134575
#
# Current batch: 300
# Current batch average train accuracy: 0.8071578286164452
# Current batch average train loss: 0.00865323469042778
#
# Total average train accuarcy: 0.7556832432913061
# Total average train loss: 0.008720403145551682
#
# [ Test epoch: 138 ]
#
# Total average test accuarcy: 0.9547
# Total average test loss: 0.007137614667415619
# Model Saved!
#
# Time elapsed: 8822.28353691101
#
# [ Train epoch: 139 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8055922404062913
# Current batch average train loss: 0.008849356323480606
#
# Current batch: 100
# Current batch average train accuracy: 0.8474592215252539
# Current batch average train loss: 0.008064359426498413
#
# Current batch: 200
# Current batch average train accuracy: 0.547692594362072
# Current batch average train loss: 0.010597809217870235
#
# Current batch: 300
# Current batch average train accuracy: 0.7605524095899551
# Current batch average train loss: 0.009101718664169312
#
# Total average train accuarcy: 0.7361721764293412
# Total average train loss: 0.008968510336875915
#
# [ Test epoch: 139 ]
#
# Total average test accuarcy: 0.9544
# Total average test loss: 0.007225336265563965
# Model Saved!
#
# Time elapsed: 8885.745553016663
#
# [ Train epoch: 140 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9556235071773277
# Current batch average train loss: 0.005419077817350626
#
# Current batch: 100
# Current batch average train accuracy: 0.7814043967960634
# Current batch average train loss: 0.009172869846224785
#
# Current batch: 200
# Current batch average train accuracy: 0.8316227765384814
# Current batch average train loss: 0.008310483768582344
#
# Current batch: 300
# Current batch average train accuracy: 0.5533594485834612
# Current batch average train loss: 0.010886652395129204
#
# Total average train accuarcy: 0.756115454101914
# Total average train loss: 0.008727042552232743
#
# [ Test epoch: 140 ]
#
# Total average test accuarcy: 0.9539
# Total average test loss: 0.0071520954430103305
# Model Saved!
#
# Time elapsed: 8949.175786495209
#
# [ Train epoch: 141 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5885225991344838
# Current batch average train loss: 0.01043330505490303
#
# Current batch: 100
# Current batch average train accuracy: 0.547716604524988
# Current batch average train loss: 0.011154145002365112
#
# Current batch: 200
# Current batch average train accuracy: 0.6879880377955243
# Current batch average train loss: 0.009894764050841331
#
# Current batch: 300
# Current batch average train accuracy: 0.8246756933264706
# Current batch average train loss: 0.008444730192422867
#
# Total average train accuarcy: 0.7592507609870273
# Total average train loss: 0.00861995889544487
#
# [ Test epoch: 141 ]
#
# Total average test accuarcy: 0.9538
# Total average test loss: 0.007174659132957458
# Model Saved!
#
# Time elapsed: 9012.782588243484
#
# [ Train epoch: 142 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9624170093814907
# Current batch average train loss: 0.005383079871535301
#
# Current batch: 100
# Current batch average train accuracy: 0.7686961596078269
# Current batch average train loss: 0.009200848639011383
#
# Current batch: 200
# Current batch average train accuracy: 0.8582995162466787
# Current batch average train loss: 0.00785790290683508
#
# Current batch: 300
# Current batch average train accuracy: 0.9672325801084548
# Current batch average train loss: 0.005267905071377754
#
# Total average train accuarcy: 0.7611817099001278
# Total average train loss: 0.00860646525979042
#
# [ Test epoch: 142 ]
#
# Total average test accuarcy: 0.956
# Total average test loss: 0.00712072548866272
# Model Saved!
#
# Time elapsed: 9076.249086856842
#
# [ Train epoch: 143 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9292399820863465
# Current batch average train loss: 0.0063379080966115
#
# Current batch: 100
# Current batch average train accuracy: 0.5482897934788007
# Current batch average train loss: 0.011379038915038109
#
# Current batch: 200
# Current batch average train accuracy: 0.5677245888551622
# Current batch average train loss: 0.010791439563035965
#
# Current batch: 300
# Current batch average train accuracy: 0.8542086673477017
# Current batch average train loss: 0.0077993315644562244
#
# Total average train accuarcy: 0.7555709251459458
# Total average train loss: 0.008690866626501084
#
# [ Test epoch: 143 ]
#
# Total average test accuarcy: 0.9568
# Total average test loss: 0.007213643336296082
# Model Saved!
#
# Time elapsed: 9139.674649000168
#
# [ Train epoch: 144 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6908088918962602
# Current batch average train loss: 0.010105198249220848
#
# Current batch: 100
# Current batch average train accuracy: 0.8765129783781617
# Current batch average train loss: 0.007467205636203289
#
# Current batch: 200
# Current batch average train accuracy: 0.7330630394417006
# Current batch average train loss: 0.00963109452277422
#
# Current batch: 300
# Current batch average train accuracy: 0.6601140469628083
# Current batch average train loss: 0.010328658856451511
#
# Total average train accuarcy: 0.7508130486210928
# Total average train loss: 0.008788956874608993
#
# [ Test epoch: 144 ]
#
# Total average test accuarcy: 0.9554
# Total average test loss: 0.007178495121002197
# Model Saved!
#
# Time elapsed: 9203.25936794281
#
# [ Train epoch: 145 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6783609202952144
# Current batch average train loss: 0.010020880028605461
#
# Current batch: 100
# Current batch average train accuracy: 0.5362676279161399
# Current batch average train loss: 0.011360842734575272
#
# Current batch: 200
# Current batch average train accuracy: 0.9346147683841739
# Current batch average train loss: 0.006127160973846912
#
# Current batch: 300
# Current batch average train accuracy: 0.6740517498189977
# Current batch average train loss: 0.010260642506182194
#
# Total average train accuarcy: 0.7414821339261377
# Total average train loss: 0.008892314487695695
#
# [ Test epoch: 145 ]
#
# Total average test accuarcy: 0.9554
# Total average test loss: 0.007065882134437561
# Model Saved!
#
# Time elapsed: 9266.77291059494
#
# [ Train epoch: 146 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7176393680341391
# Current batch average train loss: 0.00976359099149704
#
# Current batch: 100
# Current batch average train accuracy: 0.7507206470004798
# Current batch average train loss: 0.009314613416790962
#
# Current batch: 200
# Current batch average train accuracy: 0.9522671439920342
# Current batch average train loss: 0.005668914411216974
#
# Current batch: 300
# Current batch average train accuracy: 0.9611200642433364
# Current batch average train loss: 0.00548010878264904
#
# Total average train accuarcy: 0.7445950403628092
# Total average train loss: 0.008779017900228501
#
# [ Test epoch: 146 ]
#
# Total average test accuarcy: 0.9551
# Total average test loss: 0.007226750206947327
# Model Saved!
#
# Time elapsed: 9330.156208992004
#
# [ Train epoch: 147 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.554471562055626
# Current batch average train loss: 0.011008337140083313
#
# Current batch: 100
# Current batch average train accuracy: 0.901439712505169
# Current batch average train loss: 0.006802666932344437
#
# Current batch: 200
# Current batch average train accuracy: 0.9903984999404876
# Current batch average train loss: 0.0045874230563640594
#
# Current batch: 300
# Current batch average train accuracy: 0.5959419633029486
# Current batch average train loss: 0.010156940668821335
#
# Total average train accuarcy: 0.7348378057771693
# Total average train loss: 0.008924039806127548
#
# [ Test epoch: 147 ]
#
# Total average test accuarcy: 0.9578
# Total average test loss: 0.006986722701787949
# Model Saved!
#
# Time elapsed: 9393.63375878334
#
# [ Train epoch: 148 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8902570276783631
# Current batch average train loss: 0.007163689471781254
#
# Current batch: 100
# Current batch average train accuracy: 0.7952976344609529
# Current batch average train loss: 0.008850880898535252
#
# Current batch: 200
# Current batch average train accuracy: 0.6952310577544383
# Current batch average train loss: 0.00975610502064228
#
# Current batch: 300
# Current batch average train accuracy: 0.606582816052638
# Current batch average train loss: 0.010176783427596092
#
# Total average train accuarcy: 0.7553971777964752
# Total average train loss: 0.008725919392108917
#
# [ Test epoch: 148 ]
#
# Total average test accuarcy: 0.9567
# Total average test loss: 0.007183362168073654
# Model Saved!
#
# Time elapsed: 9457.059406280518
#
# [ Train epoch: 149 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7607834137203116
# Current batch average train loss: 0.009437832050025463
#
# Current batch: 100
# Current batch average train accuracy: 0.8279074804864178
# Current batch average train loss: 0.008322719484567642
#
# Current batch: 200
# Current batch average train accuracy: 0.9482753044072688
# Current batch average train loss: 0.005810684524476528
#
# Current batch: 300
# Current batch average train accuracy: 0.6375253421243603
# Current batch average train loss: 0.010057277046144009
#
# Total average train accuarcy: 0.7539257533836464
# Total average train loss: 0.008709212822914123
#
# [ Test epoch: 149 ]
#
# Total average test accuarcy: 0.956
# Total average test loss: 0.007155173504352569
# Model Saved!
#
# Time elapsed: 9520.480247497559
